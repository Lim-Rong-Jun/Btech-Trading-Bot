# %% [markdown]
# # Brief Idea of Futures Grid
#
# The futures grid bot helps traders buy low and sell high, making profits by matching orders. When a buy order is executed, a new sell order is placed above it. Conversely, when a sell order is executed, a new buy order is placed underneath it.
#
#
# The bot buys low and sells high only within a certain price range. If the price goes beyond its limits, the bot stops trading until it returns to the specified range.
# While a bot offers potential benefits, futures trading comes with risks. The use of leverage can lead to significant losses in the event of unfavorable market conditions. In addition, if the margin falls below a predetermined level, liquidation may begin.
#
#  Futures trading is based on a commitment to buy or sell a specific asset (such as a cryptocurrency) at a fixed price, but the actual transaction occurs on a set date in the future.

# %% [markdown]
# # Import Libraries

# %%
import ccxt
import pandas as pd ## 
import numpy as np
from datetime import datetime, timedelta ## 
import time ## 
# import matplotlib.pyplot as plt
# Out:
# /Users/belinda/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# # Getting Data from Binance for BTC

# %%
# Use your Binance API credentials
exchange = ccxt.binance({
    'apiKey': 'rKI3q7RZSOwaKmtEdpJr8gzW2ck32ZXVAUWhwajXU88pHlrm0cnKqyHWy2n2gbRJ',
    'secret': 'RfA74xF2DloTmJcHSVsIMnpk7YbHhfI4iV1SVv8NIR1pHf1rnCl8n14hfNSWXTiu',
    'options': {'defaultType': 'future'}  # Ensure futures trading mode
})

# Fetch the order book for a symbol (e.g., 'BTC/USDT')
order_book = exchange.fetch_order_book('BTC/USDT')

# %% [markdown]
# # Creating the Parameters for the Bot

# %% [markdown]
# ###
# Arithmetic: Each grid has an equal price difference. Better for Low-volatility assets
#
# Geometric: Each grid has an equal price difference ratio. Better for High-volatility assets

# %%
# Grid Trading Parameters
symbol = 'BTC/USDT'  # Trading pair
grid_levels = 10  # Number of grid orders
grid_spacing = 50  # Price gap between grid orders
order_size = 0.01  # Order size in BTC
leverage = 1 # Leverage multiplier
grid_type = 'arithmetic'  # or 'geometric'

# %%
# Set leverage properly
exchange.set_leverage(leverage, symbol)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': '1', 'maxNotionalValue': '1800000000'}

# %%
# # Get initial price
# price_data = exchange.fetch_ticker(symbol)
# initial_price = price_data['last']
# print('Initial Price: ', initial_price)
# # Generate grid price levels
# grid_prices = [initial_price + (i - grid_levels // 2) * grid_spacing for i in range(grid_levels)]
# print('Grid Prices: ', grid_prices)

# %%
# Initialize Binance exchange (without API keys for public data)
exchange = ccxt.binance()

# Fetch historical data (Example: BTC/USDT, 1-minute timeframe)
bars = exchange.fetch_ohlcv('BTC/USDT', timeframe='1m', limit=500)

# Convert to DataFrame
df = pd.DataFrame(bars, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

# Convert timestamp to readable date
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# Save to CSV file
# df.to_csv('binance_data.csv', index=False)

df = pd.read_csv("binance_data.csv")

# Display the first and last few rows
print((df.head()), "\n\n")
print(df.tail())
# Out:
#              timestamp      open      high       low     close    volume
# 0  2025-02-11 06:43:00  98312.99  98336.79  98312.98  98329.99   8.74084
# 1  2025-02-11 06:44:00  98329.99  98346.58  98329.99  98346.57  10.12839
# 2  2025-02-11 06:45:00  98346.58  98388.89  98300.00  98300.00  29.89419
# 3  2025-02-11 06:46:00  98300.01  98332.01  98288.04  98317.50  13.23001
# 4  2025-02-11 06:47:00  98317.50  98336.43  98300.00  98300.00  10.06472
#
#
#                timestamp      open      high       low     close    volume
# 495  2025-02-11 14:58:00  96992.03  97015.84  96992.03  96996.10   9.56111
# 496  2025-02-11 14:59:00  96996.10  97000.06  96962.00  96962.03   5.03029
# 497  2025-02-11 15:00:00  96962.04  97078.29  96912.65  97045.75  45.29869
# 498  2025-02-11 15:01:00  97045.74  97130.67  97045.74  97130.67  12.14271
# 499  2025-02-11 15:02:00  97130.67  97247.09  97116.32  97214.74  14.34648

# %% [markdown]
# ## Hidden Parameters

# %%
# Hidden parameters validation
def validate_grid_parameters(initial_price, grid_levels, grid_spacing, leverage):
    # 1. Price Range
    MIN_PRICE = 556.8
    MAX_PRICE = 4529764
    # 2. Number of Grids
    MIN_GRIDS = 2
    MAX_GRIDS = 169
    # 3. Investment
     # the investment is the margin amount transferred from the futures account 
     # to create the grid. The total investment = investment * leverage. 
    MIN_LEVERAGE = 1
    MAX_LEVERAGE = 1
    # 4. Choose 'arithmetic' or 'geometric'
    grid_type = 'geometric' 

    if initial_price - (grid_levels * grid_spacing) < MIN_PRICE:
        raise ValueError("Grid buy orders exceed Binance's minimum price limit.")
    if initial_price + (grid_levels * grid_spacing) > MAX_PRICE:
        raise ValueError("Grid sell orders exceed Binance's maximum price limit.")
    if not (MIN_GRIDS <= grid_levels <= MAX_GRIDS):
        raise ValueError(f"Number of grid levels must be between {MIN_GRIDS} and {MAX_GRIDS}.")
    if not (MIN_LEVERAGE <= leverage <= MAX_LEVERAGE):
        raise ValueError(f"Leverage must be between {MIN_LEVERAGE}x and {MAX_LEVERAGE}x.")

    print("Hidden parameters validated successfully.")

# Validate parameters before trading
try:
    validate_grid_parameters(initial_price, grid_levels, grid_spacing, leverage)
    print("Proceeding to buy and sell...")
    last_trade = None
except ValueError as e:
    print("Validation Error:", e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 30
#      28 # Validate parameters before trading
#      29 try:
# ---> 30     validate_grid_parameters(initial_price, grid_levels, grid_spacing, leverage)
#      31     print("Proceeding to buy and sell...")
#      32     last_trade = None
#
# NameError: name 'initial_price' is not defined

# %%
# # Fetch current BTC/USDT price
# ticker = exchange.fetch_ticker('BTC/USDT')
# current_price = ticker['last']
# print(f"Current BTC Price: {current_price}")

# # Generate dynamic grid prices (±1% steps)
# grid_step = 0.01  # 1% per step
# num_grids = 5     # Number of grid levels

# grid_prices = sorted([
#     round(current_price * (1 + grid_step * i), 2) for i in range(-num_grids, num_grids + 1)
# ])

# print(f"Grid Prices: {grid_prices}")

# # Load historical data
# df['time'] = pd.to_datetime(df['timestamp'])
# df.set_index('time', inplace=True)

# # Track last trade direction
# last_trade = None  

# # Simulate trading
# for index, row in df.iterrows():
#     price = row['close']

#     for grid_price in grid_prices:
#         if abs(price - grid_price) <= 10:  # Allow small variation
            
#             if last_trade == "SELL" or last_trade is None:
#                 print(f"🟢 BUY at {price} on {index}")
#                 last_trade = "BUY"
            
#             elif last_trade == "BUY":
#                 print(f"🔴 SELL at {price} on {index}")
#                 last_trade = "SELL"

# %% [markdown]
# ###
# Taker: u place a market order for a coin and then pay a taker fee since you're taking liquidity out of the market because the order is immediate.
#
# Maker: u place a limit order for a specific price that doesn't immediately find a matching order.

# %%
# Initialize tracking variables
completed_trades = 0
total_profit = 0
trades_history = []
binance_fees = {'maker': 0.0002, 'taker': 0.0005}  # 0.02%, 0.05%


# Fetch current BTC/USDT price
ticker = exchange.fetch_ticker('BTC/USDT')
current_price = ticker['last']
print(f"Current BTC Price: {current_price}")

# Generate grid prices
if grid_type == 'arithmetic':
    grid_prices = sorted([
        round(current_price + (grid_spacing * i), 2) 
        for i in range(-grid_levels // 2, grid_levels // 2 + 1)
    ])
else:  # geometric
    ratio = 1.936204  # Apply the provided ratio
    grid_prices = sorted([
        round(current_price * (ratio ** i), 2) 
        for i in range(-grid_levels // 2, grid_levels // 2 + 1)
    ])

print(f"Grid Prices: {grid_prices}")

# Load historical data
df['time'] = pd.to_datetime(df['timestamp'])  # Convert timestamps to datetime
df.set_index('time', inplace=True)  # Set time as index for easy lookup

# Track last trade direction and price
last_trade = None
last_trade_price = None

# Simulate trading
for index, row in df.iterrows():  # Loop through historical data
    price = row['close']  # Get the closing price of each time period

    for grid_price in grid_prices:
        if abs(price - grid_price) <= 10:  # Allow small variation
            effective_size = order_size * leverage  # Apply leverage to position size
            
            if last_trade == "SELL" or last_trade is None:
                print(f"🟢 BUY {effective_size} {symbol} at {price} on {index}")
                last_trade = "BUY"
                last_trade_price = price
                
                trades_history.append({
                    'timestamp': index,
                    'type': 'BUY',
                    'price': price,
                    'grid_price': grid_price,
                    'size': effective_size
                })
                
            elif last_trade == "BUY":
                print(f"🔴 SELL {effective_size} {symbol} at {price} on {index}")
                
                # Calculate profit for this completed grid
                buy_price = last_trade_price
                sell_price = price
                
                # Calculate fees (considering leverage)
                #buy_fee = buy_price * effective_size * binance_fees['maker']
                #sell_fee = sell_price * effective_size * binance_fees['maker']
                
                # Calculate profit (with leverage)
                trade_profit = (sell_price - buy_price) * effective_size
                total_profit += trade_profit
                completed_trades += 1
                
                trades_history.append({
                    'timestamp': index,
                    'type': 'SELL',
                    'price': price,
                    'grid_price': grid_price,
                    'size': effective_size,
                    'profit': trade_profit
                })
                
                print(f"Trade {completed_trades}: " \
                      f"Buy at {buy_price:.2f}, Sell at {sell_price:.2f}, " \
                      f"Profit: {trade_profit:.6f} USDT (with {leverage}x leverage)")
                
                last_trade = "SELL"
                last_trade_price = None

    # Update grid prices periodically based on current price
    if grid_type == 'arithmetic':
        grid_prices = sorted([
            round(price + (grid_spacing * i), 2) 
            for i in range(-grid_levels // 2, grid_levels // 2 + 1)
        ])
    else:  # geometric
        grid_prices = sorted([
            round(price * (ratio ** i), 2) 
            for i in range(-grid_levels // 2, grid_levels // 2 + 1)
        ])

# Print Final Trading Summary
if completed_trades > 0:
    avg_profit_per_grid = total_profit / completed_trades
    print("\nTrading Summary:")
    print(f"Symbol: {symbol}")
    print(f"Leverage: {leverage}x")
    print(f"Total Profit: {total_profit:.6f} USDT")
    print(f"Completed Trades: {completed_trades}")
    print(f"Average Profit per Grid: {avg_profit_per_grid:.6f} USDT")
    print(f"Profit Percentage: {(avg_profit_per_grid / current_price * 100):.4f}%")
    print(f"Effective Order Size: {order_size * leverage} {symbol.split('/')[0]}")
# Out:
# Current BTC Price: 97742.42
# Grid Prices: [97492.42, 97542.42, 97592.42, 97642.42, 97692.42, 97742.42, 97792.42, 97842.42, 97892.42, 97942.42, 97992.42]
# 🟢 BUY 0.1 BTC/USDT at 97346.91 on 2025-02-07 05:21:00
# 🔴 SELL 0.1 BTC/USDT at 97252.34 on 2025-02-07 05:24:00
# Trade 1: Buy at 97346.91, Sell at 97252.34, Profit: -13.348985 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97210.74 on 2025-02-07 05:29:00
# 🔴 SELL 0.1 BTC/USDT at 97213.44 on 2025-02-07 05:30:00
# Trade 2: Buy at 97210.74, Sell at 97213.44, Profit: -3.618484 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97328.01 on 2025-02-07 05:41:00
# 🔴 SELL 0.1 BTC/USDT at 97369.57 on 2025-02-07 05:42:00
# Trade 3: Buy at 97328.01, Sell at 97369.57, Profit: 0.262048 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97370.43 on 2025-02-07 05:43:00
# 🔴 SELL 0.1 BTC/USDT at 97300.01 on 2025-02-07 05:45:00
# Trade 4: Buy at 97370.43, Sell at 97300.01, Profit: -10.935409 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97279.34 on 2025-02-07 05:47:00
# 🔴 SELL 0.1 BTC/USDT at 97304.63 on 2025-02-07 05:51:00
# Trade 5: Buy at 97279.34, Sell at 97304.63, Profit: -1.362679 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97251.18 on 2025-02-07 05:52:00
# 🔴 SELL 0.1 BTC/USDT at 97303.11 on 2025-02-07 05:54:00
# Trade 6: Buy at 97251.18, Sell at 97303.11, Profit: 1.301914 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97341.38 on 2025-02-07 06:00:00
# 🔴 SELL 0.1 BTC/USDT at 97289.25 on 2025-02-07 06:01:00
# Trade 7: Buy at 97341.38, Sell at 97289.25, Profit: -9.105613 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97229.37 on 2025-02-07 06:02:00
# 🔴 SELL 0.1 BTC/USDT at 97300.0 on 2025-02-07 06:04:00
# Trade 8: Buy at 97229.37, Sell at 97300.00, Profit: 3.172413 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97298.47 on 2025-02-07 06:05:00
# 🔴 SELL 0.1 BTC/USDT at 97239.14 on 2025-02-07 06:06:00
# Trade 9: Buy at 97298.47, Sell at 97239.14, Profit: -9.823752 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97186.45 on 2025-02-07 06:07:00
# 🔴 SELL 0.1 BTC/USDT at 97180.18 on 2025-02-07 06:10:00
# Trade 10: Buy at 97186.45, Sell at 97180.18, Profit: -4.514333 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97219.0 on 2025-02-07 06:12:00
# 🔴 SELL 0.1 BTC/USDT at 97271.73 on 2025-02-07 06:13:00
# Trade 11: Buy at 97219.00, Sell at 97271.73, Profit: 1.383185 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97121.63 on 2025-02-07 06:22:00
# 🔴 SELL 0.1 BTC/USDT at 97078.01 on 2025-02-07 06:23:00
# Trade 12: Buy at 97121.63, Sell at 97078.01, Profit: -8.245993 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97125.45 on 2025-02-07 06:24:00
# 🔴 SELL 0.1 BTC/USDT at 97052.17 on 2025-02-07 06:27:00
# Trade 13: Buy at 97125.45, Sell at 97052.17, Profit: -11.211552 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96910.68 on 2025-02-07 06:32:00
# 🔴 SELL 0.1 BTC/USDT at 96853.32 on 2025-02-07 06:33:00
# Trade 14: Buy at 96910.68, Sell at 96853.32, Profit: -9.611280 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96587.24 on 2025-02-07 06:35:00
# 🔴 SELL 0.1 BTC/USDT at 96847.22 on 2025-02-07 06:39:00
# Trade 15: Buy at 96587.24, Sell at 96847.22, Profit: 22.129311 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96704.41 on 2025-02-07 06:45:00
# 🔴 SELL 0.1 BTC/USDT at 96650.77 on 2025-02-07 06:46:00
# Trade 16: Buy at 96704.41, Sell at 96650.77, Profit: -9.231104 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96757.52 on 2025-02-07 06:47:00
# 🔴 SELL 0.1 BTC/USDT at 96787.98 on 2025-02-07 06:49:00
# Trade 17: Buy at 96757.52, Sell at 96787.98, Profit: -0.824910 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96837.14 on 2025-02-07 06:54:00
# 🔴 SELL 0.1 BTC/USDT at 96831.71 on 2025-02-07 06:55:00
# Trade 18: Buy at 96837.14, Sell at 96831.71, Profit: -4.416377 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96785.06 on 2025-02-07 06:56:00
# 🔴 SELL 0.1 BTC/USDT at 96623.81 on 2025-02-07 06:58:00
# Trade 19: Buy at 96785.06, Sell at 96623.81, Profit: -19.993177 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96925.35 on 2025-02-07 07:05:00
# 🔴 SELL 0.1 BTC/USDT at 96965.66 on 2025-02-07 07:06:00
# Trade 20: Buy at 96925.35, Sell at 96965.66, Profit: 0.153180 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96961.62 on 2025-02-07 07:10:00
# 🔴 SELL 0.1 BTC/USDT at 96910.36 on 2025-02-07 07:13:00
# Trade 21: Buy at 96961.62, Sell at 96910.36, Profit: -9.003440 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96908.79 on 2025-02-07 07:14:00
# 🔴 SELL 0.1 BTC/USDT at 96991.99 on 2025-02-07 07:16:00
# Trade 22: Buy at 96908.79, Sell at 96991.99, Profit: 4.441984 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97143.37 on 2025-02-07 07:19:00
# 🔴 SELL 0.1 BTC/USDT at 97084.88 on 2025-02-07 07:20:00
# Trade 23: Buy at 97143.37, Sell at 97084.88, Profit: -9.733565 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97046.87 on 2025-02-07 07:27:00
# 🔴 SELL 0.1 BTC/USDT at 96943.21 on 2025-02-07 07:30:00
# Trade 24: Buy at 97046.87, Sell at 96943.21, Profit: -14.245802 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96934.21 on 2025-02-07 07:31:00
# 🔴 SELL 0.1 BTC/USDT at 96941.03 on 2025-02-07 07:34:00
# Trade 25: Buy at 96934.21, Sell at 96941.03, Profit: -3.195505 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96981.59 on 2025-02-07 07:35:00
# 🔴 SELL 0.1 BTC/USDT at 96914.41 on 2025-02-07 07:37:00
# Trade 26: Buy at 96981.59, Sell at 96914.41, Profit: -10.595920 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96858.93 on 2025-02-07 07:38:00
# 🔴 SELL 0.1 BTC/USDT at 96765.49 on 2025-02-07 07:48:00
# Trade 27: Buy at 96858.93, Sell at 96765.49, Profit: -13.216488 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96725.91 on 2025-02-07 07:51:00
# 🔴 SELL 0.1 BTC/USDT at 96723.44 on 2025-02-07 07:52:00
# Trade 28: Buy at 96725.91, Sell at 96723.44, Profit: -4.115987 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96705.19 on 2025-02-07 07:54:00
# 🔴 SELL 0.1 BTC/USDT at 96657.91 on 2025-02-07 07:55:00
# Trade 29: Buy at 96705.19, Sell at 96657.91, Profit: -8.595262 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96748.79 on 2025-02-07 07:57:00
# 🔴 SELL 0.1 BTC/USDT at 96757.05 on 2025-02-07 07:59:00
# Trade 30: Buy at 96748.79, Sell at 96757.05, Profit: -3.044117 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96673.65 on 2025-02-07 08:01:00
# 🔴 SELL 0.1 BTC/USDT at 96695.21 on 2025-02-07 08:03:00
# Trade 31: Buy at 96673.65, Sell at 96695.21, Profit: -1.711377 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96686.99 on 2025-02-07 08:04:00
# 🔴 SELL 0.1 BTC/USDT at 96939.51 on 2025-02-07 08:09:00
# Trade 32: Buy at 96686.99, Sell at 96939.51, Profit: 21.379470 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96893.99 on 2025-02-07 08:10:00
# 🔴 SELL 0.1 BTC/USDT at 96832.0 on 2025-02-07 08:12:00
# Trade 33: Buy at 96893.99, Sell at 96832.00, Profit: -10.073520 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96880.44 on 2025-02-07 08:18:00
# 🔴 SELL 0.1 BTC/USDT at 96896.0 on 2025-02-07 08:20:00
# Trade 34: Buy at 96880.44, Sell at 96896.00, Profit: -2.319529 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96827.17 on 2025-02-07 08:23:00
# 🔴 SELL 0.1 BTC/USDT at 96791.98 on 2025-02-07 08:26:00
# Trade 35: Buy at 96827.17, Sell at 96791.98, Profit: -7.391383 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96874.24 on 2025-02-07 08:28:00
# 🔴 SELL 0.1 BTC/USDT at 96872.74 on 2025-02-07 08:29:00
# Trade 36: Buy at 96874.24, Sell at 96872.74, Profit: -4.024940 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 96909.33 on 2025-02-07 08:33:00
# 🔴 SELL 0.1 BTC/USDT at 96974.02 on 2025-02-07 08:39:00
# Trade 37: Buy at 96909.33, Sell at 96974.02, Profit: 2.591333 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97121.99 on 2025-02-07 08:44:00
# 🔴 SELL 0.1 BTC/USDT at 97214.79 on 2025-02-07 08:47:00
# Trade 38: Buy at 97121.99, Sell at 97214.79, Profit: 5.393264 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97096.11 on 2025-02-07 08:50:00
# 🔴 SELL 0.1 BTC/USDT at 97081.93 on 2025-02-07 08:54:00
# Trade 39: Buy at 97096.11, Sell at 97081.93, Profit: -5.301561 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97014.87 on 2025-02-07 08:56:00
# 🔴 SELL 0.1 BTC/USDT at 97030.72 on 2025-02-07 08:58:00
# Trade 40: Buy at 97014.87, Sell at 97030.72, Profit: -2.295912 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97021.47 on 2025-02-07 08:59:00
# 🔴 SELL 0.1 BTC/USDT at 97129.94 on 2025-02-07 09:01:00
# Trade 41: Buy at 97021.47, Sell at 97129.94, Profit: 6.963972 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97179.0 on 2025-02-07 09:06:00
# 🔴 SELL 0.1 BTC/USDT at 97177.49 on 2025-02-07 09:10:00
# Trade 42: Buy at 97179.00, Sell at 97177.49, Profit: -4.038130 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97239.13 on 2025-02-07 09:15:00
# 🔴 SELL 0.1 BTC/USDT at 97342.93 on 2025-02-07 09:17:00
# Trade 43: Buy at 97239.13, Sell at 97342.93, Profit: 6.488359 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97340.01 on 2025-02-07 09:18:00
# 🔴 SELL 0.1 BTC/USDT at 97286.01 on 2025-02-07 09:19:00
# Trade 44: Buy at 97340.01, Sell at 97286.01, Profit: -9.292520 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97333.74 on 2025-02-07 09:20:00
# 🔴 SELL 0.1 BTC/USDT at 97378.63 on 2025-02-07 09:21:00
# Trade 45: Buy at 97333.74, Sell at 97378.63, Profit: 0.594753 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97300.0 on 2025-02-07 09:26:00
# 🔴 SELL 0.1 BTC/USDT at 97292.72 on 2025-02-07 09:27:00
# Trade 46: Buy at 97300.00, Sell at 97292.72, Profit: -4.619854 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97284.7 on 2025-02-07 09:28:00
# 🔴 SELL 0.1 BTC/USDT at 97281.99 on 2025-02-07 09:29:00
# Trade 47: Buy at 97284.70, Sell at 97281.99, Profit: -4.162334 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97279.35 on 2025-02-07 09:30:00
# 🔴 SELL 0.1 BTC/USDT at 97223.31 on 2025-02-07 09:33:00
# Trade 48: Buy at 97279.35, Sell at 97223.31, Profit: -9.494053 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97227.51 on 2025-02-07 09:34:00
# 🔴 SELL 0.1 BTC/USDT at 97227.52 on 2025-02-07 09:35:00
# Trade 49: Buy at 97227.51, Sell at 97227.52, Profit: -3.888101 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97274.85 on 2025-02-07 09:38:00
# 🔴 SELL 0.1 BTC/USDT at 97272.3 on 2025-02-07 09:39:00
# Trade 50: Buy at 97274.85, Sell at 97272.30, Profit: -4.145943 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97321.18 on 2025-02-07 09:44:00
# 🔴 SELL 0.1 BTC/USDT at 97291.9 on 2025-02-07 09:47:00
# Trade 51: Buy at 97321.18, Sell at 97291.90, Profit: -6.820262 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97284.82 on 2025-02-07 09:49:00
# 🔴 SELL 0.1 BTC/USDT at 97336.96 on 2025-02-07 09:54:00
# Trade 52: Buy at 97284.82, Sell at 97336.96, Profit: 1.321564 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97295.23 on 2025-02-07 09:59:00
# 🔴 SELL 0.1 BTC/USDT at 97352.0 on 2025-02-07 10:00:00
# Trade 53: Buy at 97295.23, Sell at 97352.00, Profit: 1.784055 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97305.84 on 2025-02-07 10:01:00
# 🔴 SELL 0.1 BTC/USDT at 97258.3 on 2025-02-07 10:02:00
# Trade 54: Buy at 97305.84, Sell at 97258.30, Profit: -8.645283 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97346.22 on 2025-02-07 10:04:00
# 🔴 SELL 0.1 BTC/USDT at 97356.01 on 2025-02-07 10:05:00
# Trade 55: Buy at 97346.22, Sell at 97356.01, Profit: -2.915045 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97351.98 on 2025-02-07 10:08:00
# 🔴 SELL 0.1 BTC/USDT at 97333.39 on 2025-02-07 10:10:00
# Trade 56: Buy at 97351.98, Sell at 97333.39, Profit: -5.752707 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97298.51 on 2025-02-07 10:13:00
# 🔴 SELL 0.1 BTC/USDT at 97326.35 on 2025-02-07 10:16:00
# Trade 57: Buy at 97298.51, Sell at 97326.35, Profit: -1.108497 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97425.58 on 2025-02-07 10:24:00
# 🔴 SELL 0.1 BTC/USDT at 97427.86 on 2025-02-07 10:25:00
# Trade 58: Buy at 97425.58, Sell at 97427.86, Profit: -3.669069 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97434.3 on 2025-02-07 10:26:00
# 🔴 SELL 0.1 BTC/USDT at 97467.6 on 2025-02-07 10:30:00
# Trade 59: Buy at 97434.30, Sell at 97467.60, Profit: -0.568038 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97421.27 on 2025-02-07 10:31:00
# 🔴 SELL 0.1 BTC/USDT at 97413.27 on 2025-02-07 10:33:00
# Trade 60: Buy at 97421.27, Sell at 97413.27, Profit: -4.696691 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97466.6 on 2025-02-07 10:42:00
# 🔴 SELL 0.1 BTC/USDT at 97336.96 on 2025-02-07 10:44:00
# Trade 61: Buy at 97466.60, Sell at 97336.96, Profit: -16.860071 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97265.86 on 2025-02-07 10:47:00
# 🔴 SELL 0.1 BTC/USDT at 97345.2 on 2025-02-07 10:51:00
# Trade 62: Buy at 97265.86, Sell at 97345.20, Profit: 4.041779 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97326.76 on 2025-02-07 10:57:00
# 🔴 SELL 0.1 BTC/USDT at 97270.3 on 2025-02-07 10:58:00
# Trade 63: Buy at 97326.76, Sell at 97270.30, Profit: -9.537941 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97261.51 on 2025-02-07 10:59:00
# 🔴 SELL 0.1 BTC/USDT at 97302.87 on 2025-02-07 11:00:00
# Trade 64: Buy at 97261.51, Sell at 97302.87, Profit: 0.244712 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97387.19 on 2025-02-07 11:06:00
# 🔴 SELL 0.1 BTC/USDT at 97443.21 on 2025-02-07 11:07:00
# Trade 65: Buy at 97387.19, Sell at 97443.21, Profit: 1.705392 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97494.45 on 2025-02-07 11:08:00
# 🔴 SELL 0.1 BTC/USDT at 97546.19 on 2025-02-07 11:09:00
# Trade 66: Buy at 97494.45, Sell at 97546.19, Profit: 1.273187 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97599.99 on 2025-02-07 11:10:00
# 🔴 SELL 0.1 BTC/USDT at 97656.94 on 2025-02-07 11:11:00
# Trade 67: Buy at 97599.99, Sell at 97656.94, Profit: 1.789861 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97627.92 on 2025-02-07 11:15:00
# 🔴 SELL 0.1 BTC/USDT at 97699.99 on 2025-02-07 11:20:00
# Trade 68: Buy at 97627.92, Sell at 97699.99, Profit: 3.300442 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97630.43 on 2025-02-07 11:26:00
# 🔴 SELL 0.1 BTC/USDT at 97630.44 on 2025-02-07 11:27:00
# Trade 69: Buy at 97630.43, Sell at 97630.44, Profit: -3.904217 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97577.25 on 2025-02-07 11:31:00
# 🔴 SELL 0.1 BTC/USDT at 97626.42 on 2025-02-07 11:35:00
# Trade 70: Buy at 97577.25, Sell at 97626.42, Profit: 1.012927 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97629.51 on 2025-02-07 11:39:00
# 🔴 SELL 0.1 BTC/USDT at 97686.47 on 2025-02-07 11:40:00
# Trade 71: Buy at 97629.51, Sell at 97686.47, Profit: 1.789680 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97652.31 on 2025-02-07 11:42:00
# 🔴 SELL 0.1 BTC/USDT at 97622.92 on 2025-02-07 11:47:00
# Trade 72: Buy at 97652.31, Sell at 97622.92, Profit: -6.844505 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97629.57 on 2025-02-07 11:48:00
# 🔴 SELL 0.1 BTC/USDT at 97634.46 on 2025-02-07 11:49:00
# Trade 73: Buy at 97629.57, Sell at 97634.46, Profit: -3.416281 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97711.99 on 2025-02-07 11:51:00
# 🔴 SELL 0.1 BTC/USDT at 97630.76 on 2025-02-07 11:53:00
# Trade 74: Buy at 97711.99, Sell at 97630.76, Profit: -12.029855 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97739.99 on 2025-02-07 11:56:00
# 🔴 SELL 0.1 BTC/USDT at 97737.97 on 2025-02-07 11:57:00
# Trade 75: Buy at 97739.99, Sell at 97737.97, Profit: -4.111559 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97737.97 on 2025-02-07 11:58:00
# 🔴 SELL 0.1 BTC/USDT at 97868.25 on 2025-02-07 12:04:00
# Trade 76: Buy at 97737.97, Sell at 97868.25, Profit: 9.115876 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97771.92 on 2025-02-07 12:05:00
# 🔴 SELL 0.1 BTC/USDT at 97769.28 on 2025-02-07 12:06:00
# Trade 77: Buy at 97771.92, Sell at 97769.28, Profit: -4.174824 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97768.54 on 2025-02-07 12:07:00
# 🔴 SELL 0.1 BTC/USDT at 97779.14 on 2025-02-07 12:10:00
# Trade 78: Buy at 97768.54, Sell at 97779.14, Profit: -2.850954 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97631.58 on 2025-02-07 12:13:00
# 🔴 SELL 0.1 BTC/USDT at 97630.44 on 2025-02-07 12:14:00
# Trade 79: Buy at 97631.58, Sell at 97630.44, Profit: -4.019240 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97673.58 on 2025-02-07 12:15:00
# 🔴 SELL 0.1 BTC/USDT at 97681.99 on 2025-02-07 12:18:00
# Trade 80: Buy at 97673.58, Sell at 97681.99, Profit: -3.066111 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97602.5 on 2025-02-07 12:20:00
# 🔴 SELL 0.1 BTC/USDT at 97686.53 on 2025-02-07 12:27:00
# Trade 81: Buy at 97602.50, Sell at 97686.53, Profit: 4.497219 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97685.51 on 2025-02-07 12:29:00
# 🔴 SELL 0.1 BTC/USDT at 97937.8 on 2025-02-07 12:38:00
# Trade 82: Buy at 97685.51, Sell at 97937.80, Profit: 21.316534 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97956.0 on 2025-02-07 12:43:00
# 🔴 SELL 0.1 BTC/USDT at 97980.0 on 2025-02-07 12:49:00
# Trade 83: Buy at 97956.00, Sell at 97980.00, Profit: -1.518720 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97922.01 on 2025-02-07 12:51:00
# 🔴 SELL 0.1 BTC/USDT at 97902.49 on 2025-02-07 12:54:00
# Trade 84: Buy at 97922.01, Sell at 97902.49, Profit: -5.868490 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97892.68 on 2025-02-07 12:55:00
# 🔴 SELL 0.1 BTC/USDT at 97922.25 on 2025-02-07 12:58:00
# Trade 85: Buy at 97892.68, Sell at 97922.25, Profit: -0.959299 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97963.58 on 2025-02-07 12:59:00
# 🔴 SELL 0.1 BTC/USDT at 97970.55 on 2025-02-07 13:00:00
# Trade 86: Buy at 97963.58, Sell at 97970.55, Profit: -3.221683 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97779.11 on 2025-02-07 13:09:00
# 🔴 SELL 0.1 BTC/USDT at 97744.5 on 2025-02-07 13:11:00
# Trade 87: Buy at 97779.11, Sell at 97744.50, Profit: -7.371472 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97691.25 on 2025-02-07 13:12:00
# 🔴 SELL 0.1 BTC/USDT at 97744.6 on 2025-02-07 13:13:00
# Trade 88: Buy at 97691.25, Sell at 97744.60, Profit: 1.426283 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97673.68 on 2025-02-07 13:15:00
# 🔴 SELL 0.1 BTC/USDT at 97725.85 on 2025-02-07 13:18:00
# Trade 89: Buy at 97673.68, Sell at 97725.85, Profit: 1.309009 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97694.33 on 2025-02-07 13:20:00
# 🔴 SELL 0.1 BTC/USDT at 97600.01 on 2025-02-07 13:21:00
# Trade 90: Buy at 97694.33, Sell at 97600.01, Profit: -13.337887 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97620.0 on 2025-02-07 13:23:00
# 🔴 SELL 0.1 BTC/USDT at 97696.34 on 2025-02-07 13:25:00
# Trade 91: Buy at 97620.00, Sell at 97696.34, Profit: 3.727673 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97694.26 on 2025-02-07 13:28:00
# 🔴 SELL 0.1 BTC/USDT at 97689.84 on 2025-02-07 13:29:00
# Trade 92: Buy at 97694.26, Sell at 97689.84, Profit: -4.349682 USDT (with 10x leverage)
# 🟢 BUY 0.1 BTC/USDT at 97778.41 on 2025-02-07 13:37:00
#
# Trading Summary:
# Symbol: BTC/USDT
# Leverage: 10x
# Total Profit: -270.455890 USDT
# Completed Trades: 92
# Average Profit per Grid: -2.939738 USDT
# Profit Percentage: -0.0030%
# Effective Order Size: 0.1 BTC

# %%
# # calculating Binance geometric ratio based on the numbers auto-fill-in
# def calculate_geometric_ratio(total_range, grid_levels):
#     """
#     Calculate the geometric ratio for grid trading.

#     :param total_range: The total price range as a percentage (e.g., 1.05 for 5% range)
#     :param grid_levels: The total number of grid levels
#     :return: The calculated ratio
#     """
#     return np.exp(np.log(total_range) / (grid_levels // 2))

# # Example usage:
# total_range = 20149.6  # 5% range
# grid_levels = 30  # Total grid levels
# ratio = calculate_geometric_ratio(total_range, grid_levels)

# print(f"Geometric Ratio: {ratio:.6f}")
