# %% [markdown]
# # Brief Idea of Futures Grid
#
# The futures grid bot helps traders buy low and sell high, making profits by matching orders. When a buy order is executed, a new sell order is placed above it. Conversely, when a sell order is executed, a new buy order is placed underneath it.
#
#
# The bot buys low and sells high only within a certain price range. If the price goes beyond its limits, the bot stops trading until it returns to the specified range.
# While a bot offers potential benefits, futures trading comes with risks. The use of leverage can lead to significant losses in the event of unfavorable market conditions. In addition, if the margin falls below a predetermined level, liquidation may begin.
#
#  Futures trading is based on a commitment to buy or sell a specific asset (such as a cryptocurrency) at a fixed price, but the actual transaction occurs on a set date in the future.

# %% [markdown]
# # Import Libraries

# %%
import ccxt
import pandas as pd ## 
import numpy as np
from datetime import datetime, timedelta ## 
import time ## 
# import matplotlib.pyplot as plt

# %% [markdown]
# # Getting Data from Binance for BTC

# %%
# Use your Binance API credentials
exchange = ccxt.binance({
    'apiKey': 'rKI3q7RZSOwaKmtEdpJr8gzW2ck32ZXVAUWhwajXU88pHlrm0cnKqyHWy2n2gbRJ',
    'secret': 'RfA74xF2DloTmJcHSVsIMnpk7YbHhfI4iV1SVv8NIR1pHf1rnCl8n14hfNSWXTiu',
    'options': {'defaultType': 'future'}  # Ensure futures trading mode
})

# Fetch the order book for a symbol (e.g., 'BTC/USDT')
order_book = exchange.fetch_order_book('BTC/USDT')

# %% [markdown]
# # Creating the Parameters for the Bot

# %% [markdown]
# ###
# Arithmetic: Each grid has an equal price difference. Better for Low-volatility assets
#
# Geometric: Each grid has an equal price difference ratio. Better for High-volatility assets

# %%
# Grid Trading Parameters
symbol = 'BTC/USDT'  # Trading pair
grid_levels = 10  # Number of grid orders
grid_spacing = 50  # Price gap between grid orders
order_size = 0.01  # Order size in BTC
leverage = 1 # Leverage multiplier
grid_type = 'arithmetic'  # or 'geometric'

# %%
# Set leverage properly
exchange.set_leverage(leverage, symbol)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': '1', 'maxNotionalValue': '1800000000'}

# %%
# Get initial price
price_data = exchange.fetch_ticker(symbol)
initial_price = price_data['last']
print('Initial Price: ', initial_price)
# Generate grid price levels
grid_prices = [initial_price + (i - grid_levels // 2) * grid_spacing for i in range(grid_levels)]
print('Grid Prices: ', grid_prices)
# Out:
# Initial Price:  96915.1
# Grid Prices:  [96665.1, 96715.1, 96765.1, 96815.1, 96865.1, 96915.1, 96965.1, 97015.1, 97065.1, 97115.1]

# %%
# Initialize Binance exchange (without API keys for public data)
exchange = ccxt.binance()

# Fetch historical data (Example: BTC/USDT, 1-minute timeframe)
bars = exchange.fetch_ohlcv('BTC/USDT', timeframe='1m', limit=500)

# Convert to DataFrame
df = pd.DataFrame(bars, columns=['timestamp', 'open', 'high', 'low', 'close', 'volume'])

# Convert timestamp to readable date
df['timestamp'] = pd.to_datetime(df['timestamp'], unit='ms')

# Save to CSV file
# df.to_csv('binance_data.csv', index=False)

df = pd.read_csv("binance_data.csv")

# Display the first and last few rows
print((df.head()), "\n\n")
print(df.tail())
# Out:
#              timestamp      open      high       low     close    volume
# 0  2025-02-11 06:43:00  98312.99  98336.79  98312.98  98329.99   8.74084
# 1  2025-02-11 06:44:00  98329.99  98346.58  98329.99  98346.57  10.12839
# 2  2025-02-11 06:45:00  98346.58  98388.89  98300.00  98300.00  29.89419
# 3  2025-02-11 06:46:00  98300.01  98332.01  98288.04  98317.50  13.23001
# 4  2025-02-11 06:47:00  98317.50  98336.43  98300.00  98300.00  10.06472
#
#
#                timestamp      open      high       low     close    volume
# 495  2025-02-11 14:58:00  96992.03  97015.84  96992.03  96996.10   9.56111
# 496  2025-02-11 14:59:00  96996.10  97000.06  96962.00  96962.03   5.03029
# 497  2025-02-11 15:00:00  96962.04  97078.29  96912.65  97045.75  45.29869
# 498  2025-02-11 15:01:00  97045.74  97130.67  97045.74  97130.67  12.14271
# 499  2025-02-11 15:02:00  97130.67  97247.09  97116.32  97214.74  14.34648

# %% [markdown]
# ## Hidden Parameters

# %%
# Hidden parameters validation
def validate_grid_parameters(initial_price, grid_levels, grid_spacing, leverage):
    # 1. Price Range
    MIN_PRICE = 556.8
    MAX_PRICE = 4529764
    # 2. Number of Grids
    MIN_GRIDS = 2
    MAX_GRIDS = 169
    # 3. Investment
     # the investment is the margin amount transferred from the futures account 
     # to create the grid. The total investment = investment * leverage. 
    MIN_LEVERAGE = 1
    MAX_LEVERAGE = 1
    # 4. Choose 'arithmetic' or 'geometric'
    grid_type = 'geometric' 

    if initial_price - (grid_levels * grid_spacing) < MIN_PRICE:
        raise ValueError("Grid buy orders exceed Binance's minimum price limit.")
    if initial_price + (grid_levels * grid_spacing) > MAX_PRICE:
        raise ValueError("Grid sell orders exceed Binance's maximum price limit.")
    if not (MIN_GRIDS <= grid_levels <= MAX_GRIDS):
        raise ValueError(f"Number of grid levels must be between {MIN_GRIDS} and {MAX_GRIDS}.")
    if not (MIN_LEVERAGE <= leverage <= MAX_LEVERAGE):
        raise ValueError(f"Leverage must be between {MIN_LEVERAGE}x and {MAX_LEVERAGE}x.")

    print("Hidden parameters validated successfully.")

# Validate parameters before trading
try:
    validate_grid_parameters(initial_price, grid_levels, grid_spacing, leverage)
    print("Proceeding to buy and sell...")
    last_trade = None
except ValueError as e:
    print("Validation Error:", e)
# Out:
# Hidden parameters validated successfully.
# Proceeding to buy and sell...

# %%
# # Fetch current BTC/USDT price
# ticker = exchange.fetch_ticker('BTC/USDT')
# current_price = ticker['last']
# print(f"Current BTC Price: {current_price}")

# # Generate dynamic grid prices (±1% steps)
# grid_step = 0.01  # 1% per step
# num_grids = 5     # Number of grid levels

# grid_prices = sorted([
#     round(current_price * (1 + grid_step * i), 2) for i in range(-num_grids, num_grids + 1)
# ])

# print(f"Grid Prices: {grid_prices}")

# # Load historical data
# df['time'] = pd.to_datetime(df['timestamp'])
# df.set_index('time', inplace=True)

# # Track last trade direction
# last_trade = None  

# # Simulate trading
# for index, row in df.iterrows():
#     price = row['close']

#     for grid_price in grid_prices:
#         if abs(price - grid_price) <= 10:  # Allow small variation
            
#             if last_trade == "SELL" or last_trade is None:
#                 print(f"🟢 BUY at {price} on {index}")
#                 last_trade = "BUY"
            
#             elif last_trade == "BUY":
#                 print(f"🔴 SELL at {price} on {index}")
#                 last_trade = "SELL"

# %% [markdown]
# ###
# Taker: u place a market order for a coin and then pay a taker fee since you're taking liquidity out of the market because the order is immediate.
#
# Maker: u place a limit order for a specific price that doesn't immediately find a matching order.

# %%
# Initialize tracking variables
completed_trades = 0
total_profit = 0
trades_history = []
binance_fees = {'maker': 0.0002, 'taker': 0.0005}  # 0.02%, 0.05%


# Fetch current BTC/USDT price
ticker = exchange.fetch_ticker('BTC/USDT')
current_price = ticker['last']
print(f"Current BTC Price: {current_price}")

# Generate grid prices
if grid_type == 'arithmetic':
    grid_prices = sorted([
        round(current_price + (grid_spacing * i), 2) 
        for i in range(-grid_levels // 2, grid_levels // 2 + 1)
    ])
else:  # geometric
    ratio = 1.936204  # Apply the provided ratio
    grid_prices = sorted([
        round(current_price * (ratio ** i), 2) 
        for i in range(-grid_levels // 2, grid_levels // 2 + 1)
    ])

print(f"Grid Prices: {grid_prices}")

# Load historical data
df['time'] = pd.to_datetime(df['timestamp'])  # Convert timestamps to datetime
df.set_index('time', inplace=True)  # Set time as index for easy lookup

# Track last trade direction and price
last_trade = None
last_trade_price = None

# Simulate trading
for index, row in df.iterrows():  # Loop through historical data
    price = row['close']  # Get the closing price of each time period

    for grid_price in grid_prices:
        if abs(price - grid_price) <= 10:  # Allow small variation
            effective_size = order_size * leverage  # Apply leverage to position size
            
            if last_trade == "SELL" or last_trade is None:
                print(f"🟢 BUY {effective_size} {symbol} at {price} on {index}")
                last_trade = "BUY"
                last_trade_price = price
                
                trades_history.append({
                    'timestamp': index,
                    'type': 'BUY',
                    'price': price,
                    'grid_price': grid_price,
                    'size': effective_size
                })
                
            elif last_trade == "BUY":
                print(f"🔴 SELL {effective_size} {symbol} at {price} on {index}")
                
                # Calculate profit for this completed grid
                buy_price = last_trade_price
                sell_price = price
                
                # Calculate fees (considering leverage)
                #buy_fee = buy_price * effective_size * binance_fees['maker']
                #sell_fee = sell_price * effective_size * binance_fees['maker']
                
                # Calculate profit (with leverage)
                trade_profit = (sell_price - buy_price) * effective_size
                total_profit += trade_profit
                completed_trades += 1
                
                trades_history.append({
                    'timestamp': index,
                    'type': 'SELL',
                    'price': price,
                    'grid_price': grid_price,
                    'size': effective_size,
                    'profit': trade_profit
                })
                
                print(f"Trade {completed_trades}: " \
                      f"Buy at {buy_price:.2f}, Sell at {sell_price:.2f}, " \
                      f"Profit: {trade_profit:.6f} USDT (with {leverage}x leverage)")
                
                last_trade = "SELL"
                last_trade_price = None

    # Update grid prices periodically based on current price
    if grid_type == 'arithmetic':
        grid_prices = sorted([
            round(price + (grid_spacing * i), 2) 
            for i in range(-grid_levels // 2, grid_levels // 2 + 1)
        ])
    else:  # geometric
        grid_prices = sorted([
            round(price * (ratio ** i), 2) 
            for i in range(-grid_levels // 2, grid_levels // 2 + 1)
        ])

# Print Final Trading Summary
if completed_trades > 0:
    avg_profit_per_grid = total_profit / completed_trades
    print("\nTrading Summary:")
    print(f"Symbol: {symbol}")
    print(f"Leverage: {leverage}x")
    print(f"Total Profit: {total_profit:.6f} USDT")
    print(f"Completed Trades: {completed_trades}")
    print(f"Average Profit per Grid: {avg_profit_per_grid:.6f} USDT")
    print(f"Profit Percentage: {(avg_profit_per_grid / current_price * 100):.4f}%")
    print(f"Effective Order Size: {order_size * leverage} {symbol.split('/')[0]}")
# Out:
# Current BTC Price: 96968.9
# Grid Prices: [96718.9, 96768.9, 96818.9, 96868.9, 96918.9, 96968.9, 97018.9, 97068.9, 97118.9, 97168.9, 97218.9]
# 🟢 BUY 0.01 BTC/USDT at 98300.0 on 2025-02-11 06:45:00
# 🔴 SELL 0.01 BTC/USDT at 98460.32 on 2025-02-11 06:52:00
# Trade 1: Buy at 98300.00, Sell at 98460.32, Profit: 1.603200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98424.71 on 2025-02-11 06:56:00
# 🔴 SELL 0.01 BTC/USDT at 98442.83 on 2025-02-11 06:58:00
# Trade 2: Buy at 98424.71, Sell at 98442.83, Profit: 0.181200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98350.9 on 2025-02-11 07:01:00
# 🔴 SELL 0.01 BTC/USDT at 98384.88 on 2025-02-11 07:03:00
# Trade 3: Buy at 98350.90, Sell at 98384.88, Profit: 0.339800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98376.13 on 2025-02-11 07:04:00
# 🔴 SELL 0.01 BTC/USDT at 98421.71 on 2025-02-11 07:05:00
# Trade 4: Buy at 98376.13, Sell at 98421.71, Profit: 0.455800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98353.17 on 2025-02-11 07:07:00
# 🔴 SELL 0.01 BTC/USDT at 98363.64 on 2025-02-11 07:13:00
# Trade 5: Buy at 98353.17, Sell at 98363.64, Profit: 0.104700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98362.01 on 2025-02-11 07:14:00
# 🔴 SELL 0.01 BTC/USDT at 98363.63 on 2025-02-11 07:15:00
# Trade 6: Buy at 98362.01, Sell at 98363.63, Profit: 0.016200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98375.56 on 2025-02-11 07:17:00
# 🔴 SELL 0.01 BTC/USDT at 98375.67 on 2025-02-11 07:18:00
# Trade 7: Buy at 98375.56, Sell at 98375.67, Profit: 0.001100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98378.03 on 2025-02-11 07:19:00
# 🔴 SELL 0.01 BTC/USDT at 98380.19 on 2025-02-11 07:20:00
# Trade 8: Buy at 98378.03, Sell at 98380.19, Profit: 0.021600 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98375.87 on 2025-02-11 07:21:00
# 🔴 SELL 0.01 BTC/USDT at 98348.9 on 2025-02-11 07:24:00
# Trade 9: Buy at 98375.87, Sell at 98348.90, Profit: -0.269700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98413.43 on 2025-02-11 07:27:00
# 🔴 SELL 0.01 BTC/USDT at 98408.43 on 2025-02-11 07:28:00
# Trade 10: Buy at 98413.43, Sell at 98408.43, Profit: -0.050000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98413.44 on 2025-02-11 07:29:00
# 🔴 SELL 0.01 BTC/USDT at 98399.0 on 2025-02-11 07:32:00
# Trade 11: Buy at 98413.44, Sell at 98399.00, Profit: -0.144400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98349.08 on 2025-02-11 07:33:00
# 🔴 SELL 0.01 BTC/USDT at 98364.98 on 2025-02-11 07:35:00
# Trade 12: Buy at 98349.08, Sell at 98364.98, Profit: 0.159000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98427.98 on 2025-02-11 07:44:00
# 🔴 SELL 0.01 BTC/USDT at 98343.83 on 2025-02-11 07:46:00
# Trade 13: Buy at 98427.98, Sell at 98343.83, Profit: -0.841500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98348.49 on 2025-02-11 07:49:00
# 🔴 SELL 0.01 BTC/USDT at 98294.07 on 2025-02-11 07:53:00
# Trade 14: Buy at 98348.49, Sell at 98294.07, Profit: -0.544200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98320.75 on 2025-02-11 07:55:00
# 🔴 SELL 0.01 BTC/USDT at 98303.03 on 2025-02-11 07:57:00
# Trade 15: Buy at 98320.75, Sell at 98303.03, Profit: -0.177200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98229.0 on 2025-02-11 08:04:00
# 🔴 SELL 0.01 BTC/USDT at 98179.89 on 2025-02-11 08:05:00
# Trade 16: Buy at 98229.00, Sell at 98179.89, Profit: -0.491100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98208.65 on 2025-02-11 08:07:00
# 🔴 SELL 0.01 BTC/USDT at 98151.52 on 2025-02-11 08:11:00
# Trade 17: Buy at 98208.65, Sell at 98151.52, Profit: -0.571300 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98199.99 on 2025-02-11 08:14:00
# 🔴 SELL 0.01 BTC/USDT at 98181.81 on 2025-02-11 08:16:00
# Trade 18: Buy at 98199.99, Sell at 98181.81, Profit: -0.181800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98172.56 on 2025-02-11 08:17:00
# 🔴 SELL 0.01 BTC/USDT at 98164.74 on 2025-02-11 08:21:00
# Trade 19: Buy at 98172.56, Sell at 98164.74, Profit: -0.078200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98118.17 on 2025-02-11 08:27:00
# 🔴 SELL 0.01 BTC/USDT at 98115.89 on 2025-02-11 08:28:00
# Trade 20: Buy at 98118.17, Sell at 98115.89, Profit: -0.022800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98109.3 on 2025-02-11 08:29:00
# 🔴 SELL 0.01 BTC/USDT at 98224.61 on 2025-02-11 08:45:00
# Trade 21: Buy at 98109.30, Sell at 98224.61, Profit: 1.153100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98182.72 on 2025-02-11 08:46:00
# 🔴 SELL 0.01 BTC/USDT at 98192.44 on 2025-02-11 08:47:00
# Trade 22: Buy at 98182.72, Sell at 98192.44, Profit: 0.097200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98202.01 on 2025-02-11 08:49:00
# 🔴 SELL 0.01 BTC/USDT at 98182.86 on 2025-02-11 08:51:00
# Trade 23: Buy at 98202.01, Sell at 98182.86, Profit: -0.191500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98182.87 on 2025-02-11 08:52:00
# 🔴 SELL 0.01 BTC/USDT at 98182.87 on 2025-02-11 08:53:00
# Trade 24: Buy at 98182.87, Sell at 98182.87, Profit: 0.000000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98207.0 on 2025-02-11 08:57:00
# 🔴 SELL 0.01 BTC/USDT at 98223.79 on 2025-02-11 08:59:00
# Trade 25: Buy at 98207.00, Sell at 98223.79, Profit: 0.167900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98272.72 on 2025-02-11 09:00:00
# 🔴 SELL 0.01 BTC/USDT at 98279.22 on 2025-02-11 09:01:00
# Trade 26: Buy at 98272.72, Sell at 98279.22, Profit: 0.065000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98274.32 on 2025-02-11 09:04:00
# 🔴 SELL 0.01 BTC/USDT at 98300.05 on 2025-02-11 09:06:00
# Trade 27: Buy at 98274.32, Sell at 98300.05, Profit: 0.257300 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98254.9 on 2025-02-11 09:07:00
# 🔴 SELL 0.01 BTC/USDT at 98245.28 on 2025-02-11 09:08:00
# Trade 28: Buy at 98254.90, Sell at 98245.28, Profit: -0.096200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98287.75 on 2025-02-11 09:12:00
# 🔴 SELL 0.01 BTC/USDT at 98241.13 on 2025-02-11 09:13:00
# Trade 29: Buy at 98287.75, Sell at 98241.13, Profit: -0.466200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98234.48 on 2025-02-11 09:14:00
# 🔴 SELL 0.01 BTC/USDT at 98242.43 on 2025-02-11 09:16:00
# Trade 30: Buy at 98234.48, Sell at 98242.43, Profit: 0.079500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98207.55 on 2025-02-11 09:18:00
# 🔴 SELL 0.01 BTC/USDT at 98100.01 on 2025-02-11 09:20:00
# Trade 31: Buy at 98207.55, Sell at 98100.01, Profit: -1.075400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98160.99 on 2025-02-11 09:26:00
# 🔴 SELL 0.01 BTC/USDT at 98196.97 on 2025-02-11 09:28:00
# Trade 32: Buy at 98160.99, Sell at 98196.97, Profit: 0.359800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98189.18 on 2025-02-11 09:29:00
# 🔴 SELL 0.01 BTC/USDT at 98171.0 on 2025-02-11 09:32:00
# Trade 33: Buy at 98189.18, Sell at 98171.00, Profit: -0.181800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98126.12 on 2025-02-11 09:33:00
# 🔴 SELL 0.01 BTC/USDT at 98070.01 on 2025-02-11 09:36:00
# Trade 34: Buy at 98126.12, Sell at 98070.01, Profit: -0.561100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98062.51 on 2025-02-11 09:37:00
# 🔴 SELL 0.01 BTC/USDT at 98070.81 on 2025-02-11 09:38:00
# Trade 35: Buy at 98062.51, Sell at 98070.81, Profit: 0.083000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98070.8 on 2025-02-11 09:39:00
# 🔴 SELL 0.01 BTC/USDT at 98009.83 on 2025-02-11 09:41:00
# Trade 36: Buy at 98070.80, Sell at 98009.83, Profit: -0.609700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98000.0 on 2025-02-11 09:43:00
# 🔴 SELL 0.01 BTC/USDT at 98017.5 on 2025-02-11 09:45:00
# Trade 37: Buy at 98000.00, Sell at 98017.50, Profit: 0.175000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98061.78 on 2025-02-11 09:46:00
# 🔴 SELL 0.01 BTC/USDT at 98084.21 on 2025-02-11 09:48:00
# Trade 38: Buy at 98061.78, Sell at 98084.21, Profit: 0.224300 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98039.3 on 2025-02-11 09:50:00
# 🔴 SELL 0.01 BTC/USDT at 98030.29 on 2025-02-11 09:51:00
# Trade 39: Buy at 98039.30, Sell at 98030.29, Profit: -0.090100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98025.06 on 2025-02-11 09:53:00
# 🔴 SELL 0.01 BTC/USDT at 97999.99 on 2025-02-11 09:59:00
# Trade 40: Buy at 98025.06, Sell at 97999.99, Profit: -0.250700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98055.36 on 2025-02-11 10:00:00
# 🔴 SELL 0.01 BTC/USDT at 98126.16 on 2025-02-11 10:11:00
# Trade 41: Buy at 98055.36, Sell at 98126.16, Profit: 0.708000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98129.27 on 2025-02-11 10:12:00
# 🔴 SELL 0.01 BTC/USDT at 98128.57 on 2025-02-11 10:13:00
# Trade 42: Buy at 98129.27, Sell at 98128.57, Profit: -0.007000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98067.79 on 2025-02-11 10:17:00
# 🔴 SELL 0.01 BTC/USDT at 98103.1 on 2025-02-11 10:19:00
# Trade 43: Buy at 98067.79, Sell at 98103.10, Profit: 0.353100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98042.01 on 2025-02-11 10:26:00
# 🔴 SELL 0.01 BTC/USDT at 97949.83 on 2025-02-11 10:27:00
# Trade 44: Buy at 98042.01, Sell at 97949.83, Profit: -0.921800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97909.37 on 2025-02-11 10:28:00
# 🔴 SELL 0.01 BTC/USDT at 97912.49 on 2025-02-11 10:29:00
# Trade 45: Buy at 97909.37, Sell at 97912.49, Profit: 0.031200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97963.28 on 2025-02-11 10:30:00
# 🔴 SELL 0.01 BTC/USDT at 97963.29 on 2025-02-11 10:31:00
# Trade 46: Buy at 97963.28, Sell at 97963.29, Profit: 0.000100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97956.93 on 2025-02-11 10:32:00
# 🔴 SELL 0.01 BTC/USDT at 97967.18 on 2025-02-11 10:34:00
# Trade 47: Buy at 97956.93, Sell at 97967.18, Profit: 0.102500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97999.49 on 2025-02-11 10:36:00
# 🔴 SELL 0.01 BTC/USDT at 97999.87 on 2025-02-11 10:37:00
# Trade 48: Buy at 97999.49, Sell at 97999.87, Profit: 0.003800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97999.9 on 2025-02-11 10:38:00
# 🔴 SELL 0.01 BTC/USDT at 98009.27 on 2025-02-11 10:39:00
# Trade 49: Buy at 97999.90, Sell at 98009.27, Profit: 0.093700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97999.99 on 2025-02-11 10:40:00
# 🔴 SELL 0.01 BTC/USDT at 97998.25 on 2025-02-11 10:41:00
# Trade 50: Buy at 97999.99, Sell at 97998.25, Profit: -0.017400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97971.38 on 2025-02-11 10:44:00
# 🔴 SELL 0.01 BTC/USDT at 98015.86 on 2025-02-11 10:45:00
# Trade 51: Buy at 97971.38, Sell at 98015.86, Profit: 0.444800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98013.35 on 2025-02-11 10:48:00
# 🔴 SELL 0.01 BTC/USDT at 98026.19 on 2025-02-11 10:50:00
# Trade 52: Buy at 98013.35, Sell at 98026.19, Profit: 0.128400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98026.19 on 2025-02-11 10:51:00
# 🔴 SELL 0.01 BTC/USDT at 97961.24 on 2025-02-11 10:58:00
# Trade 53: Buy at 98026.19, Sell at 97961.24, Profit: -0.649500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97961.25 on 2025-02-11 10:59:00
# 🔴 SELL 0.01 BTC/USDT at 97965.47 on 2025-02-11 11:00:00
# Trade 54: Buy at 97961.25, Sell at 97965.47, Profit: 0.042200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97965.47 on 2025-02-11 11:01:00
# 🔴 SELL 0.01 BTC/USDT at 98015.46 on 2025-02-11 11:02:00
# Trade 55: Buy at 97965.47, Sell at 98015.46, Profit: 0.499900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98017.05 on 2025-02-11 11:03:00
# 🔴 SELL 0.01 BTC/USDT at 98017.05 on 2025-02-11 11:04:00
# Trade 56: Buy at 98017.05, Sell at 98017.05, Profit: 0.000000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98017.06 on 2025-02-11 11:05:00
# 🔴 SELL 0.01 BTC/USDT at 97987.65 on 2025-02-11 11:07:00
# Trade 57: Buy at 98017.06, Sell at 97987.65, Profit: -0.294100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97950.51 on 2025-02-11 11:09:00
# 🔴 SELL 0.01 BTC/USDT at 97915.98 on 2025-02-11 11:11:00
# Trade 58: Buy at 97950.51, Sell at 97915.98, Profit: -0.345300 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97923.57 on 2025-02-11 11:12:00
# 🔴 SELL 0.01 BTC/USDT at 97923.57 on 2025-02-11 11:13:00
# Trade 59: Buy at 97923.57, Sell at 97923.57, Profit: 0.000000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97965.85 on 2025-02-11 11:17:00
# 🔴 SELL 0.01 BTC/USDT at 97967.63 on 2025-02-11 11:18:00
# Trade 60: Buy at 97965.85, Sell at 97967.63, Profit: 0.017800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98016.24 on 2025-02-11 11:19:00
# 🔴 SELL 0.01 BTC/USDT at 98062.62 on 2025-02-11 11:22:00
# Trade 61: Buy at 98016.24, Sell at 98062.62, Profit: 0.463800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98066.82 on 2025-02-11 11:23:00
# 🔴 SELL 0.01 BTC/USDT at 98071.56 on 2025-02-11 11:24:00
# Trade 62: Buy at 98066.82, Sell at 98071.56, Profit: 0.047400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98081.09 on 2025-02-11 11:25:00
# 🔴 SELL 0.01 BTC/USDT at 98081.01 on 2025-02-11 11:26:00
# Trade 63: Buy at 98081.09, Sell at 98081.01, Profit: -0.000800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98081.01 on 2025-02-11 11:27:00
# 🔴 SELL 0.01 BTC/USDT at 98090.9 on 2025-02-11 11:28:00
# Trade 64: Buy at 98081.01, Sell at 98090.90, Profit: 0.098900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98085.29 on 2025-02-11 11:29:00
# 🔴 SELL 0.01 BTC/USDT at 98070.8 on 2025-02-11 11:34:00
# Trade 65: Buy at 98085.29, Sell at 98070.80, Profit: -0.144900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98064.74 on 2025-02-11 11:35:00
# 🔴 SELL 0.01 BTC/USDT at 97999.84 on 2025-02-11 11:41:00
# Trade 66: Buy at 98064.74, Sell at 97999.84, Profit: -0.649000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98044.28 on 2025-02-11 11:44:00
# 🔴 SELL 0.01 BTC/USDT at 98110.99 on 2025-02-11 11:47:00
# Trade 67: Buy at 98044.28, Sell at 98110.99, Profit: 0.667100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98136.36 on 2025-02-11 11:51:00
# 🔴 SELL 0.01 BTC/USDT at 98179.4 on 2025-02-11 11:52:00
# Trade 68: Buy at 98136.36, Sell at 98179.40, Profit: 0.430400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98199.99 on 2025-02-11 11:54:00
# 🔴 SELL 0.01 BTC/USDT at 98200.17 on 2025-02-11 11:55:00
# Trade 69: Buy at 98199.99, Sell at 98200.17, Profit: 0.001800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98151.33 on 2025-02-11 11:56:00
# 🔴 SELL 0.01 BTC/USDT at 98151.34 on 2025-02-11 11:57:00
# Trade 70: Buy at 98151.33, Sell at 98151.34, Profit: 0.000100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98151.51 on 2025-02-11 11:58:00
# 🔴 SELL 0.01 BTC/USDT at 98151.52 on 2025-02-11 11:59:00
# Trade 71: Buy at 98151.51, Sell at 98151.52, Profit: 0.000100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 98143.84 on 2025-02-11 12:00:00
# 🔴 SELL 0.01 BTC/USDT at 98030.3 on 2025-02-11 12:07:00
# Trade 72: Buy at 98143.84, Sell at 98030.30, Profit: -1.135400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97950.0 on 2025-02-11 12:09:00
# 🔴 SELL 0.01 BTC/USDT at 97893.93 on 2025-02-11 12:10:00
# Trade 73: Buy at 97950.00, Sell at 97893.93, Profit: -0.560700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97902.01 on 2025-02-11 12:11:00
# 🔴 SELL 0.01 BTC/USDT at 97812.0 on 2025-02-11 12:14:00
# Trade 74: Buy at 97902.01, Sell at 97812.00, Profit: -0.900100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97759.78 on 2025-02-11 12:15:00
# 🔴 SELL 0.01 BTC/USDT at 97844.85 on 2025-02-11 12:19:00
# Trade 75: Buy at 97759.78, Sell at 97844.85, Profit: 0.850700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97851.26 on 2025-02-11 12:20:00
# 🔴 SELL 0.01 BTC/USDT at 97846.0 on 2025-02-11 12:21:00
# Trade 76: Buy at 97851.26, Sell at 97846.00, Profit: -0.052600 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97899.81 on 2025-02-11 12:22:00
# 🔴 SELL 0.01 BTC/USDT at 97821.02 on 2025-02-11 12:26:00
# Trade 77: Buy at 97899.81, Sell at 97821.02, Profit: -0.787900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97691.25 on 2025-02-11 12:28:00
# 🔴 SELL 0.01 BTC/USDT at 97716.2 on 2025-02-11 12:30:00
# Trade 78: Buy at 97691.25, Sell at 97716.20, Profit: 0.249500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97723.75 on 2025-02-11 12:35:00
# 🔴 SELL 0.01 BTC/USDT at 97750.25 on 2025-02-11 12:37:00
# Trade 79: Buy at 97723.75, Sell at 97750.25, Profit: 0.265000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97738.74 on 2025-02-11 12:40:00
# 🔴 SELL 0.01 BTC/USDT at 97739.58 on 2025-02-11 12:43:00
# Trade 80: Buy at 97738.74, Sell at 97739.58, Profit: 0.008400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97739.58 on 2025-02-11 12:44:00
# 🔴 SELL 0.01 BTC/USDT at 97749.26 on 2025-02-11 12:45:00
# Trade 81: Buy at 97739.58, Sell at 97749.26, Profit: 0.096800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97850.0 on 2025-02-11 12:50:00
# 🔴 SELL 0.01 BTC/USDT at 97823.99 on 2025-02-11 12:56:00
# Trade 82: Buy at 97850.00, Sell at 97823.99, Profit: -0.260100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97804.6 on 2025-02-11 12:58:00
# 🔴 SELL 0.01 BTC/USDT at 97796.76 on 2025-02-11 13:02:00
# Trade 83: Buy at 97804.60, Sell at 97796.76, Profit: -0.078400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97803.9 on 2025-02-11 13:03:00
# 🔴 SELL 0.01 BTC/USDT at 97830.16 on 2025-02-11 13:05:00
# Trade 84: Buy at 97803.90, Sell at 97830.16, Profit: 0.262600 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97830.17 on 2025-02-11 13:06:00
# 🔴 SELL 0.01 BTC/USDT at 97722.22 on 2025-02-11 13:10:00
# Trade 85: Buy at 97830.17, Sell at 97722.22, Profit: -1.079500 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97775.36 on 2025-02-11 13:11:00
# 🔴 SELL 0.01 BTC/USDT at 97772.72 on 2025-02-11 13:12:00
# Trade 86: Buy at 97775.36, Sell at 97772.72, Profit: -0.026400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97823.46 on 2025-02-11 13:13:00
# 🔴 SELL 0.01 BTC/USDT at 97799.02 on 2025-02-11 13:15:00
# Trade 87: Buy at 97823.46, Sell at 97799.02, Profit: -0.244400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97782.41 on 2025-02-11 13:17:00
# 🔴 SELL 0.01 BTC/USDT at 97747.24 on 2025-02-11 13:19:00
# Trade 88: Buy at 97782.41, Sell at 97747.24, Profit: -0.351700 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97647.51 on 2025-02-11 13:24:00
# 🔴 SELL 0.01 BTC/USDT at 97650.72 on 2025-02-11 13:25:00
# Trade 89: Buy at 97647.51, Sell at 97650.72, Profit: 0.032100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97528.04 on 2025-02-11 13:27:00
# 🔴 SELL 0.01 BTC/USDT at 97530.86 on 2025-02-11 13:28:00
# Trade 90: Buy at 97528.04, Sell at 97530.86, Profit: 0.028200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97435.99 on 2025-02-11 13:34:00
# 🔴 SELL 0.01 BTC/USDT at 97407.77 on 2025-02-11 13:41:00
# Trade 91: Buy at 97435.99, Sell at 97407.77, Profit: -0.282200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97250.3 on 2025-02-11 13:44:00
# 🔴 SELL 0.01 BTC/USDT at 97224.49 on 2025-02-11 13:46:00
# Trade 92: Buy at 97250.30, Sell at 97224.49, Profit: -0.258100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97165.73 on 2025-02-11 13:47:00
# 🔴 SELL 0.01 BTC/USDT at 96978.75 on 2025-02-11 13:50:00
# Trade 93: Buy at 97165.73, Sell at 96978.75, Profit: -1.869800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96881.77 on 2025-02-11 13:58:00
# 🔴 SELL 0.01 BTC/USDT at 96595.54 on 2025-02-11 14:00:00
# Trade 94: Buy at 96881.77, Sell at 96595.54, Profit: -2.862300 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96770.8 on 2025-02-11 14:03:00
# 🔴 SELL 0.01 BTC/USDT at 96770.26 on 2025-02-11 14:04:00
# Trade 95: Buy at 96770.80, Sell at 96770.26, Profit: -0.005400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97046.56 on 2025-02-11 14:08:00
# 🔴 SELL 0.01 BTC/USDT at 96910.56 on 2025-02-11 14:11:00
# Trade 96: Buy at 97046.56, Sell at 96910.56, Profit: -1.360000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96865.46 on 2025-02-11 14:15:00
# 🔴 SELL 0.01 BTC/USDT at 96889.5 on 2025-02-11 14:18:00
# Trade 97: Buy at 96865.46, Sell at 96889.50, Profit: 0.240400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96926.01 on 2025-02-11 14:20:00
# 🔴 SELL 0.01 BTC/USDT at 96878.72 on 2025-02-11 14:21:00
# Trade 98: Buy at 96926.01, Sell at 96878.72, Profit: -0.472900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96874.89 on 2025-02-11 14:24:00
# 🔴 SELL 0.01 BTC/USDT at 96825.51 on 2025-02-11 14:25:00
# Trade 99: Buy at 96874.89, Sell at 96825.51, Profit: -0.493800 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96829.14 on 2025-02-11 14:26:00
# 🔴 SELL 0.01 BTC/USDT at 96877.98 on 2025-02-11 14:29:00
# Trade 100: Buy at 96829.14, Sell at 96877.98, Profit: 0.488400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96859.33 on 2025-02-11 14:32:00
# 🔴 SELL 0.01 BTC/USDT at 97025.05 on 2025-02-11 14:36:00
# Trade 101: Buy at 96859.33, Sell at 97025.05, Profit: 1.657200 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96949.05 on 2025-02-11 14:39:00
# 🔴 SELL 0.01 BTC/USDT at 96994.14 on 2025-02-11 14:40:00
# Trade 102: Buy at 96949.05, Sell at 96994.14, Profit: 0.450900 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97130.63 on 2025-02-11 14:43:00
# 🔴 SELL 0.01 BTC/USDT at 97173.24 on 2025-02-11 14:44:00
# Trade 103: Buy at 97130.63, Sell at 97173.24, Profit: 0.426100 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97019.3 on 2025-02-11 14:50:00
# 🔴 SELL 0.01 BTC/USDT at 97066.64 on 2025-02-11 14:51:00
# Trade 104: Buy at 97019.30, Sell at 97066.64, Profit: 0.473400 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 97091.23 on 2025-02-11 14:54:00
# 🔴 SELL 0.01 BTC/USDT at 97051.13 on 2025-02-11 14:55:00
# Trade 105: Buy at 97091.23, Sell at 97051.13, Profit: -0.401000 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96994.39 on 2025-02-11 14:56:00
# 🔴 SELL 0.01 BTC/USDT at 96992.03 on 2025-02-11 14:57:00
# Trade 106: Buy at 96994.39, Sell at 96992.03, Profit: -0.023600 USDT (with 1x leverage)
# 🟢 BUY 0.01 BTC/USDT at 96996.1 on 2025-02-11 14:58:00
#
# Trading Summary:
# Symbol: BTC/USDT
# Leverage: 1x
# Total Profit: -8.221500 USDT
# Completed Trades: 106
# Average Profit per Grid: -0.077561 USDT
# Profit Percentage: -0.0001%
# Effective Order Size: 0.01 BTC

# %%
# # calculating Binance geometric ratio based on the numbers auto-fill-in
# def calculate_geometric_ratio(total_range, grid_levels):
#     """
#     Calculate the geometric ratio for grid trading.

#     :param total_range: The total price range as a percentage (e.g., 1.05 for 5% range)
#     :param grid_levels: The total number of grid levels
#     :return: The calculated ratio
#     """
#     return np.exp(np.log(total_range) / (grid_levels // 2))

# # Example usage:
# total_range = 20149.6  # 5% range
# grid_levels = 30  # Total grid levels
# ratio = calculate_geometric_ratio(total_range, grid_levels)

# print(f"Geometric Ratio: {ratio:.6f}")
