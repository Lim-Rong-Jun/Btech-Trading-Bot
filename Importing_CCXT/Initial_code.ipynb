# %% [markdown]
# # Initial Code for CCXT

# %%
import ccxt
# Out:
# /Users/belinda/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#import ccxt

# Initialize the exchange (e.g., Binance)
#exchange = ccxt.binance()

# Fetch ticker data for BTC/USDT
#ticker = exchange.fetch_ticker('BTC/USDT')
#print(ticker)
# Out:
# {'symbol': 'BTC/USDT', 'timestamp': 1738681879796, 'datetime': '2025-02-04T15:11:19.796Z', 'high': 102500.01, 'low': 96570.0, 'bid': 99863.87, 'bidVolume': 0.9842, 'ask': 99863.88, 'askVolume': 4.56796, 'vwap': 99651.39050007, 'open': 96645.99, 'close': 99863.88, 'last': 99863.88, 'previousClose': 96645.99, 'change': 3217.89, 'percentage': 3.33, 'average': 98254.93, 'baseVolume': 44586.85172, 'quoteVolume': 4443141771.918561, 'markPrice': None, 'indexPrice': None, 'info': {'symbol': 'BTCUSDT', 'priceChange': '3217.89000000', 'priceChangePercent': '3.330', 'weightedAvgPrice': '99651.39050007', 'prevClosePrice': '96645.99000000', 'lastPrice': '99863.88000000', 'lastQty': '0.00535000', 'bidPrice': '99863.87000000', 'bidQty': '0.98420000', 'askPrice': '99863.88000000', 'askQty': '4.56796000', 'openPrice': '96645.99000000', 'highPrice': '102500.01000000', 'lowPrice': '96570.00000000', 'volume': '44586.85172000', 'quoteVolume': '4443141771.91856070', 'openTime': '1738595479796', 'closeTime
# ...

# %%
# Use your Binance API credentials
exchange = ccxt.binance({
    'apiKey': 'WVM6uItxh6LFROouJsvpbdsJARvJYGBO6PHOdOqqDg5wRzoVIw7cZgTC7dOIKbNO',
    'secret': 'Bewg7stBp3L7c22Tl2MZ4wa7qJAqIPrNZGkAfTZE0BM5pombVpNXXltuoHF3R1Qj'
})

# Fetch the order book for a symbol (e.g., 'BTC/USDT')
order_book = exchange.fetch_order_book('ETH/USDT')

# Print the order book (top bid and ask prices)
print("Bid Prices:", order_book['bids'])  # Highest buy orders
print("Ask Prices:", order_book['asks'])  # Lowest sell orders
# Out:
# Bid Prices: [[2776.9, 0.0058], [2776.89, 0.0019], [2776.84, 0.0056], [2776.83, 0.0038], [2776.82, 0.0019], [2776.81, 0.0019], [2776.77, 0.0038], [2776.76, 2.7634], [2776.73, 0.0021], [2776.72, 0.0037], [2776.7, 0.0028], [2776.67, 3.1324], [2776.63, 0.009], [2776.62, 7.5928], [2776.54, 0.0037], [2776.52, 0.05], [2776.5, 0.0019], [2776.49, 0.7202], [2776.47, 0.0037], [2776.46, 4.2368], [2776.43, 0.0028], [2776.41, 0.0021], [2776.4, 0.0037], [2776.34, 0.0378], [2776.31, 5.3335], [2776.3, 0.0037], [2776.28, 6.3], [2776.24, 0.722], [2776.2, 1.8106], [2776.19, 0.0503], [2776.18, 0.0019], [2776.17, 0.0037], [2776.16, 0.0028], [2776.14, 0.002], [2776.11, 0.0485], [2776.08, 0.0792], [2776.06, 12.6753], [2776.05, 1.8049], [2776.0, 10.8374], [2775.99, 0.7203], [2775.98, 1.6033], [2775.97, 6.3037], [2775.96, 0.0021], [2775.95, 15.5175], [2775.92, 1.0783], [2775.89, 0.0028], [2775.87, 0.3827], [2775.85, 0.0019], [2775.84, 0.0037], [2775.83, 0.9998], [2775.8, 0.1214], [2775.78, 0.0019], [2775.77, 
# ...
