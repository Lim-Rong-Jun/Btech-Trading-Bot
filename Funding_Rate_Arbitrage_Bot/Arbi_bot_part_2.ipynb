# %%
import pandas as pd

# Load historical funding rate data
df = pd.read_csv("dataset/binance_btc_usdt_1_year_data_8h.csv")

# Parameters
min_funding_rate = 0.0001  # Minimum funding rate to consider arbitrage
trade_size = 0.01  # BTC per trade

# Function to check if arbitrage opportunity exists
def check_arbitrage_opportunity(df, min_funding_rate):
    return df[abs(df['funding_rate']) >= min_funding_rate]

# Function to determine hedge positions
def open_hedge_position(trade_size, funding_rate):
    if funding_rate > 0: 
        side_spot = 'buy'
        side_futures = 'sell'
    else:
        side_spot = 'sell'
        side_futures = 'buy'
    
    print(f"Opened hedge positions: {side_futures} futures and {side_spot} spot.")
    return side_spot, side_futures

# Function to close hedge positions
def close_positions(trade_size, funding_rate):
    if funding_rate > 0:
        side_spot = 'sell'
        side_futures = 'buy'
    else:
        side_spot = 'buy'
        side_futures = 'sell'
    
    print(f"Closed hedge positions: {side_spot} spot and {side_futures} futures.")
    return side_spot, side_futures

# Function to calculate total profit
def calculate_total_profit(trade_size, funding_rate, mark_price, entry_spot, close_spot, entry_futures, close_futures):
    """
    Calculates total funding arbitrage profit:
    - Funding fee profit
    - Spot position profit/loss
    - Futures position profit/loss
    """

    # Funding Profit (Positive if funding > 0, Negative if funding < 0)
    funding_profit = trade_size * funding_rate * mark_price

    # Determine trade direction based on funding rate
    if funding_rate > 0:
        spot_side_multiplier = 1     # Buying spot (long)
        futures_side_multiplier = -1  # Shorting futures
    else:
        spot_side_multiplier = -1     # Selling spot (short)
        futures_side_multiplier = 1   # Longing futures

    # Spot Profit/Loss
    spot_pnl = trade_size * (close_spot - entry_spot) * spot_side_multiplier

    # Futures Profit/Loss
    futures_pnl = trade_size * (entry_futures - close_futures) * futures_side_multiplier

    # Total Profit
    total_profit = funding_profit + spot_pnl + futures_pnl

    return total_profit

# Function to run the funding arbitrage bot
def funding_arbitrage_bot(df, trade_size, min_funding_rate):
    results = []

    # Filter for arbitrage opportunities
    arbitrage_df = check_arbitrage_opportunity(df, min_funding_rate)

    for index, row in arbitrage_df.iterrows():
        timestamp = row['timestamp']
        funding_rate = row['funding_rate']
        mark_price = row['close_futures']  # Mark price is usually close to futures price
        entry_spot = row['close_spot']
        entry_futures = row['close_futures']

        print(f"\n[Trade {index}] Arbitrage Opportunity Found! Funding Rate: {funding_rate}")

        # Open hedge positions
        side_spot, side_futures = open_hedge_position(trade_size, funding_rate)

        # Simulate trade closing (next row)
        if index + 1 < len(df):
            close_spot = df.loc[index + 1, 'close_spot']
            close_futures = df.loc[index + 1, 'close_futures']

            # Close positions
            close_positions(trade_size, funding_rate)

            # Calculate profit
            total_profit = calculate_total_profit(
                trade_size, funding_rate, mark_price, entry_spot, close_spot, entry_futures, close_futures
            )

            print(f"Trade Cycle Complete. Total Profit: ${total_profit:.2f}")

            # Log results
            results.append([timestamp, funding_rate, trade_size, entry_spot, close_spot, entry_futures, close_futures, total_profit])

    # Save results to CSV
    results_df = pd.DataFrame(results, columns=[
        'timestamp', 'funding_rate', 'trade_size', 'entry_spot', 'close_spot', 'entry_futures', 'close_futures', 'total_profit'
    ])
    results_df.to_csv("dataset/funding_arbitrage_results.csv", index=False)
    print("\n✅ All trades completed. Results saved to 'funding_arbitrage_results.csv'.")

# Run the bot
funding_arbitrage_bot(df, trade_size, min_funding_rate)
# Out:
# [Trade 0] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.47
#
# [Trade 1] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-25.17
#
# [Trade 2] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $19.20
#
# [Trade 3] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.93
#
# [Trade 4] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $35.27
#
# [Trade 5] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.17
#
# [Trade 6] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-0.34
#
# [Trade 7] Arbitrage Opportunity Found! Funding Rate: 0.00012282
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.44
#
# [Trade 8] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.33
#
# [Trade 9] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-2.55
#
# [Trade 10] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.84
#
# [Trade 11] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.81
#
# [Trade 12] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.22
#
# [Trade 13] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-18.42
#
# [Trade 14] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.29
#
# [Trade 15] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.58
#
# [Trade 16] Arbitrage Opportunity Found! Funding Rate: 0.00016041
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.16
#
# [Trade 17] Arbitrage Opportunity Found! Funding Rate: 0.0001724
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $7.40
#
# [Trade 18] Arbitrage Opportunity Found! Funding Rate: 0.0001530499999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $5.12
#
# [Trade 19] Arbitrage Opportunity Found! Funding Rate: 0.0001709499999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.23
#
# [Trade 20] Arbitrage Opportunity Found! Funding Rate: 0.00023064
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-6.85
#
# [Trade 21] Arbitrage Opportunity Found! Funding Rate: 0.00019594
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.30
#
# [Trade 22] Arbitrage Opportunity Found! Funding Rate: 0.00013327
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.09
#
# [Trade 23] Arbitrage Opportunity Found! Funding Rate: 0.00010461
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $11.69
#
# [Trade 24] Arbitrage Opportunity Found! Funding Rate: 0.00010912
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-13.82
#
# [Trade 25] Arbitrage Opportunity Found! Funding Rate: 0.00020259
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.18
#
# [Trade 26] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.93
#
# [Trade 27] Arbitrage Opportunity Found! Funding Rate: 0.00011242
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-0.33
#
# [Trade 28] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.51
#
# [Trade 29] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-6.22
#
# [Trade 30] Arbitrage Opportunity Found! Funding Rate: 0.00013479
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.30
#
# [Trade 31] Arbitrage Opportunity Found! Funding Rate: 0.00012557
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-0.13
#
# [Trade 32] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.28
#
# [Trade 33] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.58
#
# [Trade 34] Arbitrage Opportunity Found! Funding Rate: 0.00012991
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.62
#
# [Trade 35] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $9.51
#
# [Trade 36] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.11
#
# [Trade 37] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.99
#
# [Trade 38] Arbitrage Opportunity Found! Funding Rate: 0.00011438
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.28
#
# [Trade 39] Arbitrage Opportunity Found! Funding Rate: 0.00015012
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.65
#
# [Trade 40] Arbitrage Opportunity Found! Funding Rate: 0.00015061
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $31.02
#
# [Trade 41] Arbitrage Opportunity Found! Funding Rate: 0.00026761
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $32.88
#
# [Trade 42] Arbitrage Opportunity Found! Funding Rate: 0.00021567
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $31.83
#
# [Trade 43] Arbitrage Opportunity Found! Funding Rate: 0.00027227
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.77
#
# [Trade 44] Arbitrage Opportunity Found! Funding Rate: 0.0003226199999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.09
#
# [Trade 45] Arbitrage Opportunity Found! Funding Rate: 0.00073521
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $24.71
#
# [Trade 46] Arbitrage Opportunity Found! Funding Rate: 0.00022965
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $54.39
#
# [Trade 47] Arbitrage Opportunity Found! Funding Rate: 0.00026729
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $29.70
#
# [Trade 48] Arbitrage Opportunity Found! Funding Rate: 0.00023682
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $5.63
#
# [Trade 49] Arbitrage Opportunity Found! Funding Rate: 0.00053538
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.42
#
# [Trade 50] Arbitrage Opportunity Found! Funding Rate: 0.00069091
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-31.99
#
# [Trade 51] Arbitrage Opportunity Found! Funding Rate: 0.00076337
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.32
#
# [Trade 52] Arbitrage Opportunity Found! Funding Rate: 0.00057031
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-2.85
#
# [Trade 53] Arbitrage Opportunity Found! Funding Rate: 0.00053322
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $22.52
#
# [Trade 54] Arbitrage Opportunity Found! Funding Rate: 0.00064824
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-6.94
#
# [Trade 55] Arbitrage Opportunity Found! Funding Rate: 0.0004601
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.49
#
# [Trade 56] Arbitrage Opportunity Found! Funding Rate: 0.0003342599999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.42
#
# [Trade 57] Arbitrage Opportunity Found! Funding Rate: 0.00057174
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.53
#
# [Trade 58] Arbitrage Opportunity Found! Funding Rate: 0.00056395
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $11.71
#
# [Trade 59] Arbitrage Opportunity Found! Funding Rate: 0.00046266
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $19.46
#
# [Trade 60] Arbitrage Opportunity Found! Funding Rate: 0.00042989
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $19.22
#
# [Trade 61] Arbitrage Opportunity Found! Funding Rate: 0.00044598
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $47.98
#
# [Trade 62] Arbitrage Opportunity Found! Funding Rate: 0.00055071
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $36.22
#
# [Trade 63] Arbitrage Opportunity Found! Funding Rate: 0.00046833
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-41.57
#
# [Trade 64] Arbitrage Opportunity Found! Funding Rate: 0.0006362
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.03
#
# [Trade 65] Arbitrage Opportunity Found! Funding Rate: 0.0004896
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-61.10
#
# [Trade 66] Arbitrage Opportunity Found! Funding Rate: 0.00082969
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $60.17
#
# [Trade 67] Arbitrage Opportunity Found! Funding Rate: 0.00088148
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.55
#
# [Trade 68] Arbitrage Opportunity Found! Funding Rate: 0.0003628
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.96
#
# [Trade 69] Arbitrage Opportunity Found! Funding Rate: 0.00033876
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.56
#
# [Trade 70] Arbitrage Opportunity Found! Funding Rate: 0.00049354
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $17.74
#
# [Trade 71] Arbitrage Opportunity Found! Funding Rate: 0.0003031
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.64
#
# [Trade 72] Arbitrage Opportunity Found! Funding Rate: 0.00040984
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $8.66
#
# [Trade 73] Arbitrage Opportunity Found! Funding Rate: 0.00054217
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $8.08
#
# [Trade 74] Arbitrage Opportunity Found! Funding Rate: 0.00034819
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $10.25
#
# [Trade 75] Arbitrage Opportunity Found! Funding Rate: 0.00043497
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.50
#
# [Trade 76] Arbitrage Opportunity Found! Funding Rate: 0.00062913
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.48
#
# [Trade 77] Arbitrage Opportunity Found! Funding Rate: 0.00019134
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.57
#
# [Trade 78] Arbitrage Opportunity Found! Funding Rate: 0.00031281
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $21.25
#
# [Trade 79] Arbitrage Opportunity Found! Funding Rate: 0.00026407
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.09
#
# [Trade 80] Arbitrage Opportunity Found! Funding Rate: 0.0003101
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.70
#
# [Trade 81] Arbitrage Opportunity Found! Funding Rate: 0.0006345099999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $43.30
#
# [Trade 82] Arbitrage Opportunity Found! Funding Rate: 0.00054479
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.66
#
# [Trade 83] Arbitrage Opportunity Found! Funding Rate: 0.00035489
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.86
#
# [Trade 84] Arbitrage Opportunity Found! Funding Rate: 0.0007842799999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.21
#
# [Trade 85] Arbitrage Opportunity Found! Funding Rate: 0.00066396
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.66
#
# [Trade 86] Arbitrage Opportunity Found! Funding Rate: 0.0004447
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.95
#
# [Trade 87] Arbitrage Opportunity Found! Funding Rate: 0.000453
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $28.96
#
# [Trade 88] Arbitrage Opportunity Found! Funding Rate: 0.0004793499999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.79
#
# [Trade 89] Arbitrage Opportunity Found! Funding Rate: 0.00033224
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $9.19
#
# [Trade 90] Arbitrage Opportunity Found! Funding Rate: 0.0006442
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.52
#
# [Trade 91] Arbitrage Opportunity Found! Funding Rate: 0.0004540199999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-47.23
#
# [Trade 92] Arbitrage Opportunity Found! Funding Rate: 0.00024393
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $11.13
#
# [Trade 93] Arbitrage Opportunity Found! Funding Rate: 0.00038753
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-58.81
#
# [Trade 94] Arbitrage Opportunity Found! Funding Rate: 0.00038258
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.53
#
# [Trade 95] Arbitrage Opportunity Found! Funding Rate: 0.00038515
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $27.22
#
# [Trade 96] Arbitrage Opportunity Found! Funding Rate: 0.00014328
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.19
#
# [Trade 97] Arbitrage Opportunity Found! Funding Rate: 0.00015306
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-20.95
#
# [Trade 98] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-61.59
#
# [Trade 99] Arbitrage Opportunity Found! Funding Rate: 0.00023202
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.81
#
# [Trade 100] Arbitrage Opportunity Found! Funding Rate: 0.00020813
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $46.71
#
# [Trade 101] Arbitrage Opportunity Found! Funding Rate: 0.00013088
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $8.75
#
# [Trade 102] Arbitrage Opportunity Found! Funding Rate: 0.00017773
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.48
#
# [Trade 103] Arbitrage Opportunity Found! Funding Rate: 0.00024827
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-14.88
#
# [Trade 104] Arbitrage Opportunity Found! Funding Rate: 0.00020181
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.07
#
# [Trade 105] Arbitrage Opportunity Found! Funding Rate: 0.0003059699999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-58.03
#
# [Trade 106] Arbitrage Opportunity Found! Funding Rate: 0.00027195
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-12.93
#
# [Trade 107] Arbitrage Opportunity Found! Funding Rate: 0.0002692299999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-42.07
#
# [Trade 108] Arbitrage Opportunity Found! Funding Rate: 0.00029065
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $20.59
#
# [Trade 109] Arbitrage Opportunity Found! Funding Rate: 0.00024017
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.12
#
# [Trade 110] Arbitrage Opportunity Found! Funding Rate: 0.00015847
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $84.78
#
# [Trade 111] Arbitrage Opportunity Found! Funding Rate: 0.00018388
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-16.87
#
# [Trade 112] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.51
#
# [Trade 113] Arbitrage Opportunity Found! Funding Rate: 0.00010403
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-21.11
#
# [Trade 114] Arbitrage Opportunity Found! Funding Rate: 0.00019304
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.73
#
# [Trade 115] Arbitrage Opportunity Found! Funding Rate: 0.0001951
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-45.91
#
# [Trade 116] Arbitrage Opportunity Found! Funding Rate: 0.00016271
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.64
#
# [Trade 117] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $15.66
#
# [Trade 118] Arbitrage Opportunity Found! Funding Rate: 0.00011993
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $10.77
#
# [Trade 119] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-22.35
#
# [Trade 120] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.04
#
# [Trade 121] Arbitrage Opportunity Found! Funding Rate: 0.0001080599999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $21.91
#
# [Trade 122] Arbitrage Opportunity Found! Funding Rate: 0.00010351
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $30.86
#
# [Trade 123] Arbitrage Opportunity Found! Funding Rate: 0.00014616
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.73
#
# [Trade 124] Arbitrage Opportunity Found! Funding Rate: 0.00015884
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $59.59
#
# [Trade 125] Arbitrage Opportunity Found! Funding Rate: 0.00025549
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.82
#
# [Trade 126] Arbitrage Opportunity Found! Funding Rate: 0.00016323
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.32
#
# [Trade 127] Arbitrage Opportunity Found! Funding Rate: 0.00028814
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.44
#
# [Trade 128] Arbitrage Opportunity Found! Funding Rate: 0.00021963
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.10
#
# [Trade 129] Arbitrage Opportunity Found! Funding Rate: 0.00018348
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.94
#
# [Trade 130] Arbitrage Opportunity Found! Funding Rate: 0.00026763
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-17.10
#
# [Trade 131] Arbitrage Opportunity Found! Funding Rate: 0.00028757
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.26
#
# [Trade 132] Arbitrage Opportunity Found! Funding Rate: 0.00029551
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.74
#
# [Trade 133] Arbitrage Opportunity Found! Funding Rate: 0.0004363
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.00
#
# [Trade 134] Arbitrage Opportunity Found! Funding Rate: 0.00024195
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-9.89
#
# [Trade 135] Arbitrage Opportunity Found! Funding Rate: 0.00029899
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-19.49
#
# [Trade 136] Arbitrage Opportunity Found! Funding Rate: 0.0002943
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-12.09
#
# [Trade 137] Arbitrage Opportunity Found! Funding Rate: 0.0001825
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.47
#
# [Trade 138] Arbitrage Opportunity Found! Funding Rate: 0.00025455
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.16
#
# [Trade 139] Arbitrage Opportunity Found! Funding Rate: 0.0003017
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.34
#
# [Trade 140] Arbitrage Opportunity Found! Funding Rate: 0.0001962399999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.27
#
# [Trade 141] Arbitrage Opportunity Found! Funding Rate: 0.0003226699999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $14.66
#
# [Trade 142] Arbitrage Opportunity Found! Funding Rate: 0.0003436
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.83
#
# [Trade 143] Arbitrage Opportunity Found! Funding Rate: 0.00032351
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.38
#
# [Trade 144] Arbitrage Opportunity Found! Funding Rate: 0.00039889
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-33.83
#
# [Trade 145] Arbitrage Opportunity Found! Funding Rate: 0.00040301
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-26.86
#
# [Trade 146] Arbitrage Opportunity Found! Funding Rate: 0.00070161
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $28.80
#
# [Trade 147] Arbitrage Opportunity Found! Funding Rate: 0.00033491
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-63.68
#
# [Trade 148] Arbitrage Opportunity Found! Funding Rate: 0.00027469
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-31.22
#
# [Trade 149] Arbitrage Opportunity Found! Funding Rate: 0.00010926
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $11.58
#
# [Trade 150] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.54
#
# [Trade 151] Arbitrage Opportunity Found! Funding Rate: 0.0001645599999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.96
#
# [Trade 152] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.32
#
# [Trade 153] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.68
#
# [Trade 154] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $30.90
#
# [Trade 155] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $17.05
#
# [Trade 156] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-31.03
#
# [Trade 157] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $25.31
#
# [Trade 158] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-7.39
#
# [Trade 159] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.38
#
# [Trade 160] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.28
#
# [Trade 161] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $16.06
#
# [Trade 162] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $9.41
#
# [Trade 163] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.87
#
# [Trade 164] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.82
#
# [Trade 165] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $27.28
#
# [Trade 166] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $21.53
#
# [Trade 167] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-2.84
#
# [Trade 168] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-24.63
#
# [Trade 169] Arbitrage Opportunity Found! Funding Rate: 0.00035189
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-22.16
#
# [Trade 170] Arbitrage Opportunity Found! Funding Rate: 0.00020915
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-2.37
#
# [Trade 171] Arbitrage Opportunity Found! Funding Rate: 0.00020603
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.97
#
# [Trade 172] Arbitrage Opportunity Found! Funding Rate: 0.0001906
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-13.59
#
# [Trade 173] Arbitrage Opportunity Found! Funding Rate: 0.00011929
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $39.76
#
# [Trade 174] Arbitrage Opportunity Found! Funding Rate: 0.0001245699999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.21
#
# [Trade 175] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-14.72
#
# [Trade 176] Arbitrage Opportunity Found! Funding Rate: 0.00013978
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.26
#
# [Trade 177] Arbitrage Opportunity Found! Funding Rate: 0.00020153
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $15.42
#
# [Trade 178] Arbitrage Opportunity Found! Funding Rate: 0.00019763
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-28.55
#
# [Trade 179] Arbitrage Opportunity Found! Funding Rate: 0.00011257
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-44.61
#
# [Trade 180] Arbitrage Opportunity Found! Funding Rate: 0.0002563
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.77
#
# [Trade 181] Arbitrage Opportunity Found! Funding Rate: 0.00012214
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.55
#
# [Trade 182] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-74.88
#
# [Trade 183] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $10.56
#
# [Trade 184] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.63
#
# [Trade 185] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $29.40
#
# [Trade 186] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.17
#
# [Trade 187] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-33.60
#
# [Trade 188] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-23.02
#
# [Trade 190] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-34.86
#
# [Trade 203] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.65
#
# [Trade 224] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $10.09
#
# [Trade 235] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-12.25
#
# [Trade 236] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $29.27
#
# [Trade 271] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.58
#
# [Trade 272] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.24
#
# [Trade 276] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.31
#
# [Trade 278] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $29.78
#
# [Trade 296] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.22
#
# [Trade 297] Arbitrage Opportunity Found! Funding Rate: 0.00010517
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.35
#
# [Trade 298] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $14.74
#
# [Trade 299] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-25.49
#
# [Trade 300] Arbitrage Opportunity Found! Funding Rate: 0.00015759
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $11.30
#
# [Trade 301] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-33.19
#
# [Trade 302] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-2.03
#
# [Trade 303] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-16.16
#
# [Trade 304] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $23.26
#
# [Trade 305] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.74
#
# [Trade 306] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.02
#
# [Trade 307] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.57
#
# [Trade 308] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $7.32
#
# [Trade 309] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.01
#
# [Trade 310] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-9.80
#
# [Trade 311] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-6.74
#
# [Trade 312] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.79
#
# [Trade 313] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $34.98
#
# [Trade 314] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-18.90
#
# [Trade 315] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-34.85
#
# [Trade 316] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.75
#
# [Trade 317] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $0.72
#
# [Trade 318] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.92
#
# [Trade 319] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-11.34
#
# [Trade 320] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $5.46
#
# [Trade 321] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.20
#
# [Trade 322] Arbitrage Opportunity Found! Funding Rate: 0.00012558
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.93
#
# [Trade 323] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.36
#
# [Trade 324] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.47
#
# [Trade 325] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-19.26
#
# ...
# Trade Cycle Complete. Total Profit: $-3.02
#
# [Trade 898] Arbitrage Opportunity Found! Funding Rate: 0.0001409
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.84
#
# [Trade 899] Arbitrage Opportunity Found! Funding Rate: 0.00016985
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $24.40
#
# [Trade 900] Arbitrage Opportunity Found! Funding Rate: 0.00016572
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-30.79
#
# [Trade 901] Arbitrage Opportunity Found! Funding Rate: 0.0001758
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-35.28
#
# [Trade 902] Arbitrage Opportunity Found! Funding Rate: 0.00030413
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-10.13
#
# [Trade 903] Arbitrage Opportunity Found! Funding Rate: 0.0002103199999999
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-1.91
#
# [Trade 904] Arbitrage Opportunity Found! Funding Rate: 0.00011115
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-30.57
#
# [Trade 905] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.58
#
# [Trade 906] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $14.87
#
# [Trade 907] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $60.52
#
# [Trade 908] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $15.36
#
# [Trade 909] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-12.49
#
# [Trade 910] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $26.01
#
# [Trade 911] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-35.75
#
# [Trade 912] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.53
#
# [Trade 913] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.16
#
# [Trade 914] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $31.02
#
# [Trade 915] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $8.25
#
# [Trade 916] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.74
#
# [Trade 918] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.13
#
# [Trade 919] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $19.79
#
# [Trade 920] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $35.62
#
# [Trade 922] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $26.81
#
# [Trade 923] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.21
#
# [Trade 924] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $15.18
#
# [Trade 927] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-37.47
#
# [Trade 928] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.83
#
# [Trade 929] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-84.28
#
# [Trade 931] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-19.51
#
# [Trade 932] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-64.05
#
# [Trade 933] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $7.72
#
# [Trade 934] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-16.96
#
# [Trade 935] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $16.27
#
# [Trade 936] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $24.68
#
# [Trade 937] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-30.04
#
# [Trade 938] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-4.51
#
# [Trade 940] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-16.74
#
# [Trade 941] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-3.69
#
# [Trade 942] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $4.34
#
# [Trade 944] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $32.84
#
# [Trade 945] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-13.00
#
# [Trade 947] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $7.57
#
# [Trade 948] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-11.47
#
# [Trade 949] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $8.89
#
# [Trade 950] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $18.06
#
# [Trade 951] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-34.10
#
# [Trade 952] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-33.43
#
# [Trade 956] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-5.46
#
# [Trade 957] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.68
#
# [Trade 958] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.48
#
# [Trade 959] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $17.14
#
# [Trade 963] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-0.08
#
# [Trade 964] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-31.99
#
# [Trade 967] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $51.30
#
# [Trade 968] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-36.67
#
# [Trade 969] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.29
#
# [Trade 970] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $15.07
#
# [Trade 971] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $3.39
#
# [Trade 972] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $24.74
#
# [Trade 973] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $12.56
#
# [Trade 974] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $10.78
#
# [Trade 975] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-13.64
#
# [Trade 976] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $24.31
#
# [Trade 977] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $13.29
#
# [Trade 978] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $2.06
#
# [Trade 981] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.10
#
# [Trade 983] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $6.98
#
# [Trade 984] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $19.05
#
# [Trade 986] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $1.74
#
# [Trade 987] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-10.92
#
# [Trade 988] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-74.36
#
# [Trade 989] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-19.83
#
# [Trade 992] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-8.60
#
# [Trade 993] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-36.67
#
# [Trade 994] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $20.51
#
# [Trade 995] Arbitrage Opportunity Found! Funding Rate: 0.0001
# Opened hedge positions: sell futures and buy spot.
# Closed hedge positions: sell spot and buy futures.
# Trade Cycle Complete. Total Profit: $-33.71
#
# ✅ All trades completed. Results saved to 'funding_arbitrage_results.csv'.

# %% [markdown]
# Check profits

# %%
result_df = pd.read_csv("old_funding_arbitrage_results.csv")

# %%
result_df
# Out:
#                timestamp  funding_rate  trade_size  entry_spot  close_spot  \
# 0    2024-02-12 16:00:00        0.0001        0.01    49917.27    49983.09
# 1    2024-02-13 00:00:00        0.0001        0.01    49983.09    48727.47
# 2    2024-02-13 08:00:00        0.0001        0.01    48727.47    49699.59
# 3    2024-02-13 16:00:00        0.0001        0.01    49699.59    49838.93
# 4    2024-02-14 00:00:00        0.0001        0.01    49838.93    51590.00
# ..                   ...           ...         ...         ...         ...
# 584  2025-01-07 08:00:00        0.0001        0.01    97952.26    96954.61
# 585  2025-01-08 08:00:00        0.0001        0.01    95493.77    95060.61
# 586  2025-01-08 16:00:00        0.0001        0.01    95060.61    93221.59
# 587  2025-01-09 00:00:00        0.0001        0.01    93221.59    94244.02
# 588  2025-01-09 08:00:00        0.0001        0.01    94244.02    92552.49
#
#      entry_futures  close_futures  total_profit
# 0          49943.6        50019.9      1.471144
# 1          50019.9        48753.1    -25.174180
# 2          48753.1        49696.4     19.202953
# 3          49696.4        49845.0      2.929096
# 4          49845.0        51616.4     35.274545
# ..             ...            ...           ...
# 584        97915.3        96920.3    -19.828585
# 585        95450.0        95014.1     -8.595150
# 586        95014.1        93176.4    -36.672186
# 587        93176.4        94195.2     20.505476
# 588        94195.2        92505.9    -33.714105
#
# [589 rows x 8 columns]

# %%
print(result_df['total_profit'].sum())
# Out:
# 504.46451258598836
